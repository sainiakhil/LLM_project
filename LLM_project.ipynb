# %%
# !pip install PyMuPDF
# !pip install regex
# !pip install -q langchain
# !pip install sentence-transformers
# !pip install -q torch
# !pip install -q faiss-gpu
# !pip install -q -U langchain transformers bitsandbytes accelerate

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# %%
import torch
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from transformers import AutoTokenizer, pipeline
from langchain import HuggingFacePipeline
from langchain.chains import RetrievalQA
from transformers import BitsAndBytesConfig
from langchain import PromptTemplate, LLMChain
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %%
import fitz
import re
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
import os

# %%
# Function to extract text from PDF file
def extract_text_from_pdf(pdf_file):
    text = ""
    with fitz.open(pdf_file) as pdf:
        for page_num in range(pdf.page_count):
            page = pdf[page_num]
            text += page.get_text()
    return text

# Function to remove figures, tables, and in-text citations from text
def clean_text(text):
    # Remove figures and tables
    text = re.sub(r'\[[0-9]*\]', '', text)
    text = re.sub(r'\[[a-z]*\]', '', text)

    # Remove in-text citations (assuming citations are in the form of [Author, Year])
    text = re.sub(r'\[\w+\,\s\d+\]', '', text)

    return text

# Function to tokenize text into sentences
def tokenize_text(text):
    sentences = sent_tokenize(text)
    return sentences

# Main function to process PDF files
def process_pdf(pdf_file):
    # Extract text from PDF
    text = extract_text_from_pdf(pdf_file)

    # Clean text
    cleaned_text = clean_text(text)

    # Tokenize text into sentences
    sentences = tokenize_text(cleaned_text)

    # Save clean text to a new file
    with open(pdf_file.replace('.pdf', '_clean.txt'), 'w', encoding='utf-8') as file:
        for sentence in sentences:
            file.write(sentence + '\n')

# Process each research paper PDF file
pdf_files = os.listdir('/content/drive/MyDrive/Publications')

for pdf_file in pdf_files:
  file_path = os.path.join('/content/drive/MyDrive/Publications', pdf_file )
  process_pdf(file_path)

# %%
# Preprocessing the text files by removing stop words, stemming, and lemmatizing.
# Removeing citations and references from the retrieved text.

def preprocess_text(text):
    # Convert text to lowercase
    text = text.lower()

    # Tokenize the text into words
    words = word_tokenize(text)

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]

    # Initialize stemmer and lemmatizer
    stemmer = PorterStemmer()
    lemmatizer = WordNetLemmatizer()

    # Apply stemming and lemmatization
    stemmed_words = [stemmer.stem(word) for word in words]
    lemmatized_words = [lemmatizer.lemmatize(word) for word in stemmed_words]

    # Join the processed words back into a single string
    processed_text = ' '.join(lemmatized_words)

    return processed_text

def remove_citations_and_references(text):
    # Remove in-text citations (e.g., (Author, Year))
    text = re.sub(r'\([A-Za-z]+,\s\d{4}\)', '', text)

    # Remove references (e.g., [1], [2], [3])
    text = re.sub(r'\[\d+\]', '', text)

    return text

def preprocess_and_clean_text_files(directory):
    cleaned_texts = []

    # Loop through each file in the specified directory
    for filename in os.listdir(directory):
        if filename.endswith(".txt"):
            file_path = os.path.join(directory, filename)

            # Read the contents of the file
            with open(file_path, 'r', encoding='utf-8') as file:
                text = file.read()

            # Remove citations and references
            text = remove_citations_and_references(text)

            # Preprocess the text
            preprocessed_text = preprocess_text(text)

            # Append the preprocessed text to the list
            cleaned_texts.append(preprocessed_text)

    return cleaned_texts

text_files_directory = "/content/drive/MyDrive/Publications/clean files"

# Preprocess and clean text files
cleaned_texts = preprocess_and_clean_text_files(text_files_directory)

# %%
def split_text_files(text_list, chunk_size, chunk_overlap):
    # Instantiate the RecursiveCharacterTextSplitter
    splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)

    # List to store all chunks from the input text list
    all_chunks = []

    # Process each text in the input list
    for text in text_list:
        # Split the text into chunks using the splitter
        chunks = splitter.split_text(text)

        # Append the chunks to the list of all chunks
        all_chunks.extend(chunks)



    return all_chunks

# %%
# Split text files into chunks
chunks = split_text_files(cleaned_texts, chunk_size=512, chunk_overlap=0.2)

# %%
# Define the path to the pre-trained model you want to use
modelPath = "sentence-transformers/all-MiniLM-l6-v2"

# Create a dictionary with model configuration options, specifying to use the CPU for computations
model_kwargs = {'device':'cuda'}

# Create a dictionary with encoding options, specifically setting 'normalize_embeddings' to False
encode_kwargs = {'normalize_embeddings': False}

# Initialize an instance of HuggingFaceEmbeddings with the specified parameters
embeddings = HuggingFaceEmbeddings(
    model_name=modelPath,     # Provide the pre-trained model's path
    model_kwargs=model_kwargs, # Pass the model configuration options
    encode_kwargs=encode_kwargs # Pass the encoding options
)

# %%
db = FAISS.from_texts(chunks, embeddings)

# %%
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
)

# %%
model_4bit = AutoModelForCausalLM.from_pretrained( "mistralai/Mistral-7B-Instruct-v0.2", device_map="auto",quantization_config=quantization_config)

# Create a tokenizer object by loading the pretrained "mistralai/Mistral-7B-Instruct-v0.2" tokenizer.
tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-Instruct-v0.2")

# %%
question_answerer = pipeline(
    "text-generation",
    model=model_4bit,
    tokenizer=tokenizer,
    max_length=8192,
    # max_new_tokens=512,
    # return_tensors='pt',
    return_text=True
)

# Create an instance of the HuggingFacePipeline, which wraps the question-answering pipeline
# with additional model-specific arguments (temperature and max_length)
llm = HuggingFacePipeline(
    pipeline=question_answerer,
    model_kwargs = {"max_length": 8192}
)

# %%
# Create a retriever object from the 'db' using the 'as_retriever' method.
# This retriever is likely used for retrieving data or documents from the database.
retriever = db.as_retriever()

# %%
# Create a retriever object from the 'db' with a search configuration where it retrieves up to 4 relevant splits/documents.
retriever = db.as_retriever(search_kwargs={"k": 2})

# Create a question-answering instance (qa) using the RetrievalQA class.
# It's configured with a language model (llm), a chain type "refine," the retriever we created, and an option to not return source documents.
qa = RetrievalQA.from_chain_type(llm=llm, chain_type="map_reduce", retriever=retriever, return_source_documents=False)

# %%
question = "What are the variety of Multimodal and Multi-modular AI Approaches to Streamline Autism Diagnosis in Young Children?"
result = qa.run({"query": question})
print(result)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Given the following extracted parts of a long document and a question, create a final answer.
# If you don't know the answer, just say that you don't know. Don't try to make up an answer.
#
# QUESTION: Which state/country's law governs the interpretation of the contract?
# =========
# Content: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.
#
# Content: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.
#
# 11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.
#
# 11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.
#
# 11.9 No Third-Party Beneficiaries.
#
# Content: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,
# =========
# FINAL ANSWER: This Agreement is governed by English law.
#
# QUESTION: What did the president say about Michael Jackson?
# =========
# Content: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.
#
# Last year COVID-19 kept us apart. This year we are finally together again.
#
# Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.
#
# With a duty to one another to the American people to the Constitution.
#
# And with an unwavering resolve that freedom will always triumph over tyranny.
#
# Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated.
#
# He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined.
#
# He met the Ukrainian people.
#
# From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world.
#
# Groups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.
#
# Content: And we won’t stop.
#
# We have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life.
#
# Let’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.
#
# Let’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.
#
# We can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together.
#
# I recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera.
#
# They were responding to a 9-1-1 call when a man shot and killed them with a stolen gun.
#
# Officer Mora was 27 years old.
#
# Officer Rivera was 22.
#
# Both Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers.
#
# I spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.
#
# Content: And a proud Ukrainian people, who have known 30 years  of independence, have repeatedly shown that they will not tolerate anyone who tries to take their country backwards.
#
# To all Americans, I will be honest with you, as I’ve always promised. A Russian dictator, invading a foreign country, has costs around the world.
#
# And I’m taking robust action to make sure the pain of our sanctions  is targeted at Russia’s economy. And I will use every tool at our disposal to protect American businesses and consumers.
#
# Tonight, I can announce that the United States has worked with 30 other countries to release 60 Million barrels of oil from reserves around the world.
#
# America will lead that effort, releasing 30 Million barrels from our own Strategic Petroleum Reserve. And we stand ready to do more if necessary, unified with our allies.
#
# These steps will help blunt gas prices here at home. And I know the news about what’s happening can seem alarming.
#
# But I want you to know that we are going to be okay.
#
# Content: More support for patients and families.
#
# To get there, I call on Congress to fund ARPA-H, the Advanced Research Projects Agency for Health.
#
# It’s based on DARPA—the Defense Department project that led to the Internet, GPS, and so much more.
#
# ARPA-H will have a singular purpose—to drive breakthroughs in cancer, Alzheimer’s, diabetes, and more.
#
# A unity agenda for the nation.
#
# We can do this.
#
# My fellow Americans—tonight , we have gathered in a sacred space—the citadel of our democracy.
#
# In this Capitol, generation after generation, Americans have debated great questions amid great strife, and have done great things.
#
# We have fought for freedom, expanded liberty, defeated totalitarianism and terror.
#
# And built the strongest, freest, and most prosperous nation the world has ever known.
#
# Now is the hour.
#
# Our moment of responsibility.
#
# Our test of resolve and conscience, of history itself.
#
# It is in this moment that our character is formed. Our purpose is found. Our future is forged.
#
# Well I know this nation.
# =========
# FINAL ANSWER: The president did not mention Michael Jackson.
#
# QUESTION: What are the variety of Multimodal and Multi-modular AI Approaches to Streamline Autism Diagnosis in Young Children?
# =========
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# schad-hansjosten , et al . identifi predict fea- ture autism spectrum disord clinic sampl adolesc adult use machin learn- ing . sci rep. 2020 ; 10 ( 1 ) :4805. http : //doi.org/10.1038/s41598-020-61607-w pmid : 32188882 20. abba h , garberson f , liu-mayo , glover e , wall dp . multi-modular ai approach streamlin autism diagnosi young child . scientif report . 2020 ; 10 ( 1 ) :5014. http : //doi.org/10.1038/ s41598-020-61213-w pmid : 32193406 21. emerson rw , adam c , nishino , hazlett hc , wolff jj ,
# Question: What are the variety of Multimodal and Multi-modular AI Approaches to Streamline Autism Diagnosis in Young Children?
# Relevant text, if any:
# 20. Abba et al. (2020) proposed a multi-modular AI approach for autism diagnosis in young children.
# 21. Another study by Emerson et al. (2020) also employed a multi-modular AI approach for autism diagnosis in young children.
#
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# 1 scientif report | ( 2020 ) 10:5014 | http : //doi.org/10.1038/s41598-020-61213-w www.nature.com/scientificreport multi-modular ai approach streamlin autism diagnosi young child halim abba 1 , ford garberson 1 , stuart liu-mayo 1 , eric glover1 * & denni p. wall 2 autism becom press healthcar challeng . instrument use aid diagnosi time labor expens requir train clinician administ , lead long wait time at-risk child . present multi-modular , machin learning-bas ass autism compris three complementari modul
# Question: What are the variety of Multimodal and Multi-modular AI Approaches to Streamline Autism Diagnosis in Young Children?
# Relevant text, if any:
# The present study proposes a multi-modular, machine learning-based approach to autism diagnosis in young children. This approach comprises three complementary modules: (1) a speech module for analyzing speech features, (2) a facial expression module for analyzing facial expression features, and (3) a behavior module for analyzing behavioral features. The use of multiple modalities in this approach allows for a more comprehensive assessment of autism symptoms and may lead to more accurate diagnoses compared to traditional methods that rely on a single modality. The proposed approach also has the potential to streamline the diagnostic process by reducing the time and labor expenses required for clinicians and administrators, and may help address the challenge of long wait times for at-risk children. (Source: Scientific Reports, 2020, 10:5014, doi:10.1038/s41598-020-61213-w, www.nature.com/scientificreport)
# =========
# FINAL ANSWER: The relevant text describes a multi-modular AI approach to autism diagnosis in young children that uses three complementary modules: speech, facial expression, and behavior. This approach allows for a more comprehensive assessment of autism symptoms and may lead to more accurate diagnoses compared to traditional methods. It also has the potential to streamline the diagnostic process by reducing the time and labor expenses required for clinicians and administrators. (Source: Scientific Reports, 2020, 10:5014, doi:10.1038/s41598-020-61213-w, www.nature.com/scientificreport)
#
# Additional multimodal and multi-modular AI approaches to autism diagnosis in young children mentioned in the document include those proposed by Schad-Hansjosten et al. (2020) and Emerson et al. (2020), but the text does not provide enough detail to describe these approaches.

# %%
question = "What is Autism Spectrum Disorder, how it is caysed?"
result = qa.run({"query": question})
print(result)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Given the following extracted parts of a long document and a question, create a final answer.
# If you don't know the answer, just say that you don't know. Don't try to make up an answer.
#
# QUESTION: Which state/country's law governs the interpretation of the contract?
# =========
# Content: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.
#
# Content: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.
#
# 11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.
#
# 11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.
#
# 11.9 No Third-Party Beneficiaries.
#
# Content: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,
# =========
# FINAL ANSWER: This Agreement is governed by English law.
#
# QUESTION: What did the president say about Michael Jackson?
# =========
# Content: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.
#
# Last year COVID-19 kept us apart. This year we are finally together again.
#
# Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.
#
# With a duty to one another to the American people to the Constitution.
#
# And with an unwavering resolve that freedom will always triumph over tyranny.
#
# Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated.
#
# He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined.
#
# He met the Ukrainian people.
#
# From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world.
#
# Groups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.
#
# Content: And we won’t stop.
#
# We have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life.
#
# Let’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.
#
# Let’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.
#
# We can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together.
#
# I recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera.
#
# They were responding to a 9-1-1 call when a man shot and killed them with a stolen gun.
#
# Officer Mora was 27 years old.
#
# Officer Rivera was 22.
#
# Both Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers.
#
# I spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.
#
# Content: And a proud Ukrainian people, who have known 30 years  of independence, have repeatedly shown that they will not tolerate anyone who tries to take their country backwards.
#
# To all Americans, I will be honest with you, as I’ve always promised. A Russian dictator, invading a foreign country, has costs around the world.
#
# And I’m taking robust action to make sure the pain of our sanctions  is targeted at Russia’s economy. And I will use every tool at our disposal to protect American businesses and consumers.
#
# Tonight, I can announce that the United States has worked with 30 other countries to release 60 Million barrels of oil from reserves around the world.
#
# America will lead that effort, releasing 30 Million barrels from our own Strategic Petroleum Reserve. And we stand ready to do more if necessary, unified with our allies.
#
# These steps will help blunt gas prices here at home. And I know the news about what’s happening can seem alarming.
#
# But I want you to know that we are going to be okay.
#
# Content: More support for patients and families.
#
# To get there, I call on Congress to fund ARPA-H, the Advanced Research Projects Agency for Health.
#
# It’s based on DARPA—the Defense Department project that led to the Internet, GPS, and so much more.
#
# ARPA-H will have a singular purpose—to drive breakthroughs in cancer, Alzheimer’s, diabetes, and more.
#
# A unity agenda for the nation.
#
# We can do this.
#
# My fellow Americans—tonight , we have gathered in a sacred space—the citadel of our democracy.
#
# In this Capitol, generation after generation, Americans have debated great questions amid great strife, and have done great things.
#
# We have fought for freedom, expanded liberty, defeated totalitarianism and terror.
#
# And built the strongest, freest, and most prosperous nation the world has ever known.
#
# Now is the hour.
#
# Our moment of responsibility.
#
# Our test of resolve and conscience, of history itself.
#
# It is in this moment that our character is formed. Our purpose is found. Our future is forged.
#
# Well I know this nation.
# =========
# FINAL ANSWER: The president did not mention Michael Jackson.
#
# QUESTION: What is Autism Spectrum Disorder, how it is caysed?
# =========
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# autism re . 5 , 331–339 ( 2012 ) . ouss et al . translat psychiatri ( 2020 ) 10:54 page 7 7
# Question: What is Autism Spectrum Disorder, how it is caysed?
# Relevant text, if any:
# Autism Spectrum Disorder (ASD) is a neurodevelopmental disorder characterized by persistent deficits in social communication and interaction, and restricted, repetitive patterns of behavior, interests, or activities. The exact cause of ASD is unknown, but it is believed to be a result of a combination of genetic and environmental factors.
# (From Autism Spectrum Disorder, a review by Ouss et al., Translational Psychiatry, 2020, 10:54, page 7)
# Therefore, Autism Spectrum Disorder is a neurodevelopmental disorder that affects social communication and interaction, and presents with restricted, repetitive patterns of behavior, interests, or activities. The cause of ASD is not fully understood, but it is believed to be a result of a combination of genetic and environmental factors.
#
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# ass outperform accur 0.18 ( 90 % ci : 0.08 0.29 90 % ) auc 0.30 ( 90 % ci : 0.11 0.50 ) specif oper 90 % sensit . idiopath form autism spectrum disord ( asd ) known biolog caus may correspond multipl condit similar symptom . incid asd increas recent year , impact 1 59 child accord latest studies1 . asd diagnos clinic observ accord standard criteria2 relat child ’ social behavior symptom . autism said spectrum due vari sever symptom , rang rel mild social impair debilit intellectu disabil- iti , inabl chang
# Question: What is Autism Spectrum Disorder, how it is caysed?
# Relevant text, if any:
# Autism Spectrum Disorder (ASD) is a developmental disorder that is characterized by social behavior symptoms and impairments in communication and language skills. The exact cause of ASD is not known, but it is believed to correspond to multiple conditions with similar symptoms. The incidence of ASD has been increasing in recent years, impacting 1 in 59 children according to the latest studies. ASD is diagnosed clinically using standard criteria. Autism is a spectrum disorder due to the variability of severity of symptoms, ranging from mild social impairment to debilitating intellectual disability and inability to change or adapt to new environments.
#
# The exact cause of ASD is not known, but it is believed to correspond to multiple conditions with similar symptoms. The incidence of ASD has been increasing in recent years, impacting 1 in 59 children according to the latest studies. ASD is diagnosed clinically using standard criteria. Autism is a spectrum disorder due to the variability of severity of symptoms, ranging from mild social impairment to debilitating intellectual disability and inability to change or adapt to new environments.
#
# Therefore, the text provides information that Autism Spectrum Disorder (ASD) is a developmental disorder characterized by social behavior symptoms and impairments in communication and language skills. The exact cause of ASD is not known, but it is believed to correspond to multiple conditions with similar symptoms. The incidence of ASD has been increasing in recent years, and it is diagnosed clinically using standard criteria. ASD is a spectrum disorder due to the variability of severity of symptoms.
# =========
# FINAL ANSWER: Autism Spectrum Disorder (ASD) is a neurodevelopmental disorder characterized by persistent deficits in social communication and interaction, and restricted, repetitive patterns of behavior, interests, or activities. The exact cause of ASD is unknown, but it is believed to be a result of a combination of genetic and environmental factors.
#
# QUESTION: What is the capital city of France?
# =========
# Content: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.
#
# Last year COVID-19 kept us apart. This year we are finally together again.
#
# Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.
#
# With a duty to one another to the American people to the Constitution.
#
# And with an unwavering resolve that freedom will always triumph over tyranny.
#
# Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated.
#
# He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined.
#
# He met the Ukrainian people.
#
# From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world.
#
# Groups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.
#
# Content: And a proud Ukrainian people, who have known 30 years of independence, have repeatedly shown that they will not tolerate anyone who tries to take their country backwards.
#
# To all Americans, I will be honest with you, as I’ve always promised. A Russian dictator, invading a foreign country, has costs around the world.
#
# And I’m taking robust action to make sure the pain of our sanctions is targeted at Russia’s economy. And I will use every tool at our disposal to protect American businesses and consumers.
#
# Tonight, I can announce that the United States has worked with 30 other countries to release 60 Million barrels of oil from reserves around the world.
#
# America will lead that effort, releasing 30 Million barrels from our own Strategic Petroleum Reserve. And we stand ready to do more if necessary, unified with our allies.
#
# These steps will help blunt gas prices here at home. And I know the news about what’s happening can seem alarming.
#
# But I want you to know that we are going to be okay.
#
# Content: More support for patients and families.
#
# To get there, I call on Congress to fund ARPA-H, the Advanced Research Projects Agency for Health.
#
# It’s based on DARPA—the Defense Department project that led to the Internet, GPS, and so much more.
#
# ARPA-H will have a singular purpose—to drive breakthroughs in cancer, Alzheimer’s, diabetes, and more.
#
# A unity agenda for the nation.
#
# We can do this.
#
# My fellow Americans—tonight, we have gathered in a sacred space—the citadel of our democracy.
#
# In this Capitol, generation after generation, Americans have debated great questions amid great strife, and have done great things.
#
# We have fought for freedom, expanded liberty, defeated totalitarianism and terror.
#
# And built the strongest, freest, and most prosperous nation the world has ever known.
#
# Now is the hour.
#
# Our moment of responsibility.
#
# Our test of resolve and conscience, of history itself.
#
# It is in this moment that our character is formed. Our purpose is found. Our future is forged.
#
# Well I know this nation.
# =========
# FINAL ANSWER: The capital city of France is Paris. (This text does not provide the answer to the question.)

# %%
question = "What is the cure of Autism Spectrum Disorder?"
result = qa.run({"query": question})
print(result)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# generated_text Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# research applic machin learn approach earli detect autism combin questionnair home video screen halim abbas,1 ford garberson,1 eric glover,2 denni p wall1,3,4 1cognoa inc. , palo alto , ca , usa www.linkedin.com/in/halimabba , 2eric_g @ ericglover.com , 3depart pediatr , stanford univers , stanford , ca , usa , 4depart biomed data scienc , stanford univers , stanford , ca , usa correspond : cognoa inc. , palo alto , ca , usa ; halim @ cognoa.com receiv 19 septemb 2017 ; revis 16 march 2018 ; editori decis
# Question: What is the cure of Autism Spectrum Disorder?
# Relevant text, if any:
# The research team at Cognoa Inc., led by Halim Abbas, Ford Garberson, Eric Glover, Denise P. Wall, and colleagues, is developing an approach to early detect autism using a combination of questionnaires, home videos, and machine learning algorithms. The team's work has been published in various scientific journals and presented at conferences. For more information, please contact Cognoa Inc. at [halim@cognoa.com](mailto:halim@cognoa.com).
#
# This text does not provide any information about the cure of Autism Spectrum Disorder. It only mentions that the team at Cognoa Inc. is working on early detection of autism using a combination of methods.
# generated_text Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# scienc foundat china ( . 61772375 ) independ research project school inform manag wuhan univers ( : 413100032 ) . current issu full text archiv journal avail emerald insight : http : //www.emerald.com/insight/0737-8831.htm receiv 31 august 2019 revis 16 decemb 2019 accept 23 januari 2020 librari hi tech © emerald publish limit 0737-8831 doi 10.1108/lht-08-2019-0176 basi commun interperson relationship other . abnorm express promin manifest autism , also one criterion diagnosi autism . doctor diagnos autism
# Question: What is the cure of Autism Spectrum Disorder?
# Relevant text, if any:
# The current issue of the Full Text Archive Journal of High Technology, available on Emerald Insight, contains a research project conducted by the Science Foundation of China and the School of Management at Wuhan University. The study investigates the role of interpersonal relationships in the diagnosis of autism, using abnormal expressions and prominent manifestations as criteria. The doctor diagnoses autism based on these findings. However, the text does not provide any information on the cure or treatment of Autism Spectrum Disorder.
# generated_text Given the following extracted parts of a long document and a question, create a final answer.
# If you don't know the answer, just say that you don't know. Don't try to make up an answer.
#
# QUESTION: Which state/country's law governs the interpretation of the contract?
# =========
# Content: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.
#
# Content: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.
#
# 11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.
#
# 11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.
#
# 11.9 No Third-Party Beneficiaries.
#
# Content: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,
# =========
# FINAL ANSWER: This Agreement is governed by English law.
#
# QUESTION: What did the president say about Michael Jackson?
# =========
# Content: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.
#
# Last year COVID-19 kept us apart. This year we are finally together again.
#
# Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.
#
# With a duty to one another to the American people to the Constitution.
#
# And with an unwavering resolve that freedom will always triumph over tyranny.
#
# Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated.
#
# He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined.
#
# He met the Ukrainian people.
#
# From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world.
#
# Groups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.
#
# Content: And we won’t stop.
#
# We have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life.
#
# Let’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.
#
# Let’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.
#
# We can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together.
#
# I recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera.
#
# They were responding to a 9-1-1 call when a man shot and killed them with a stolen gun.
#
# Officer Mora was 27 years old.
#
# Officer Rivera was 22.
#
# Both Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers.
#
# I spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.
#
# Content: And a proud Ukrainian people, who have known 30 years  of independence, have repeatedly shown that they will not tolerate anyone who tries to take their country backwards.
#
# To all Americans, I will be honest with you, as I’ve always promised. A Russian dictator, invading a foreign country, has costs around the world.
#
# And I’m taking robust action to make sure the pain of our sanctions  is targeted at Russia’s economy. And I will use every tool at our disposal to protect American businesses and consumers.
#
# Tonight, I can announce that the United States has worked with 30 other countries to release 60 Million barrels of oil from reserves around the world.
#
# America will lead that effort, releasing 30 Million barrels from our own Strategic Petroleum Reserve. And we stand ready to do more if necessary, unified with our allies.
#
# These steps will help blunt gas prices here at home. And I know the news about what’s happening can seem alarming.
#
# But I want you to know that we are going to be okay.
#
# Content: More support for patients and families.
#
# To get there, I call on Congress to fund ARPA-H, the Advanced Research Projects Agency for Health.
#
# It’s based on DARPA—the Defense Department project that led to the Internet, GPS, and so much more.
#
# ARPA-H will have a singular purpose—to drive breakthroughs in cancer, Alzheimer’s, diabetes, and more.
#
# A unity agenda for the nation.
#
# We can do this.
#
# My fellow Americans—tonight , we have gathered in a sacred space—the citadel of our democracy.
#
# In this Capitol, generation after generation, Americans have debated great questions amid great strife, and have done great things.
#
# We have fought for freedom, expanded liberty, defeated totalitarianism and terror.
#
# And built the strongest, freest, and most prosperous nation the world has ever known.
#
# Now is the hour.
#
# Our moment of responsibility.
#
# Our test of resolve and conscience, of history itself.
#
# It is in this moment that our character is formed. Our purpose is found. Our future is forged.
#
# Well I know this nation.
# =========
# FINAL ANSWER: The president did not mention Michael Jackson.
#
# QUESTION: What is the cure of Autism Spectrum Disorder?
# =========
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# research applic machin learn approach earli detect autism combin questionnair home video screen halim abbas,1 ford garberson,1 eric glover,2 denni p wall1,3,4 1cognoa inc. , palo alto , ca , usa www.linkedin.com/in/halimabba , 2eric_g @ ericglover.com , 3depart pediatr , stanford univers , stanford , ca , usa , 4depart biomed data scienc , stanford univers , stanford , ca , usa correspond : cognoa inc. , palo alto , ca , usa ; halim @ cognoa.com receiv 19 septemb 2017 ; revis 16 march 2018 ; editori decis
# Question: What is the cure of Autism Spectrum Disorder?
# Relevant text, if any:
# The research team at Cognoa Inc., led by Halim Abbas, Ford Garberson, Eric Glover, Denise P. Wall, and colleagues, is developing an approach to early detect autism using a combination of questionnaires, home videos, and machine learning algorithms. The team's work has been published in various scientific journals and presented at conferences. For more information, please contact Cognoa Inc. at [halim@cognoa.com](mailto:halim@cognoa.com).
#
# This text does not provide any information about the cure of Autism Spectrum Disorder. It only mentions that the team at Cognoa Inc. is working on early detection of autism using a combination of methods.
#
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# scienc foundat china ( . 61772375 ) independ research project school inform manag wuhan univers ( : 413100032 ) . current issu full text archiv journal avail emerald insight : http : //www.emerald.com/insight/0737-8831.htm receiv 31 august 2019 revis 16 decemb 2019 accept 23 januari 2020 librari hi tech © emerald publish limit 0737-8831 doi 10.1108/lht-08-2019-0176 basi commun interperson relationship other . abnorm express promin manifest autism , also one criterion diagnosi autism . doctor diagnos autism
# Question: What is the cure of Autism Spectrum Disorder?
# Relevant text, if any:
# The current issue of the Full Text Archive Journal of High Technology, available on Emerald Insight, contains a research project conducted by the Science Foundation of China and the School of Management at Wuhan University. The study investigates the role of interpersonal relationships in the diagnosis of autism, using abnormal expressions and prominent manifestations as criteria. The doctor diagnoses autism based on these findings. However, the text does not provide any information on the cure or treatment of Autism Spectrum Disorder.
# =========
# FINAL ANSWER: The text does not provide any information about the cure of Autism Spectrum Disorder. It only mentions research on early detection and diagnosis.
# Given the following extracted parts of a long document and a question, create a final answer.
# If you don't know the answer, just say that you don't know. Don't try to make up an answer.
#
# QUESTION: Which state/country's law governs the interpretation of the contract?
# =========
# Content: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.
#
# Content: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.
#
# 11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.
#
# 11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.
#
# 11.9 No Third-Party Beneficiaries.
#
# Content: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,
# =========
# FINAL ANSWER: This Agreement is governed by English law.
#
# QUESTION: What did the president say about Michael Jackson?
# =========
# Content: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.
#
# Last year COVID-19 kept us apart. This year we are finally together again.
#
# Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.
#
# With a duty to one another to the American people to the Constitution.
#
# And with an unwavering resolve that freedom will always triumph over tyranny.
#
# Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated.
#
# He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined.
#
# He met the Ukrainian people.
#
# From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world.
#
# Groups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.
#
# Content: And we won’t stop.
#
# We have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life.
#
# Let’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.
#
# Let’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.
#
# We can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together.
#
# I recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera.
#
# They were responding to a 9-1-1 call when a man shot and killed them with a stolen gun.
#
# Officer Mora was 27 years old.
#
# Officer Rivera was 22.
#
# Both Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers.
#
# I spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.
#
# Content: And a proud Ukrainian people, who have known 30 years  of independence, have repeatedly shown that they will not tolerate anyone who tries to take their country backwards.
#
# To all Americans, I will be honest with you, as I’ve always promised. A Russian dictator, invading a foreign country, has costs around the world.
#
# And I’m taking robust action to make sure the pain of our sanctions  is targeted at Russia’s economy. And I will use every tool at our disposal to protect American businesses and consumers.
#
# Tonight, I can announce that the United States has worked with 30 other countries to release 60 Million barrels of oil from reserves around the world.
#
# America will lead that effort, releasing 30 Million barrels from our own Strategic Petroleum Reserve. And we stand ready to do more if necessary, unified with our allies.
#
# These steps will help blunt gas prices here at home. And I know the news about what’s happening can seem alarming.
#
# But I want you to know that we are going to be okay.
#
# Content: More support for patients and families.
#
# To get there, I call on Congress to fund ARPA-H, the Advanced Research Projects Agency for Health.
#
# It’s based on DARPA—the Defense Department project that led to the Internet, GPS, and so much more.
#
# ARPA-H will have a singular purpose—to drive breakthroughs in cancer, Alzheimer’s, diabetes, and more.
#
# A unity agenda for the nation.
#
# We can do this.
#
# My fellow Americans—tonight , we have gathered in a sacred space—the citadel of our democracy.
#
# In this Capitol, generation after generation, Americans have debated great questions amid great strife, and have done great things.
#
# We have fought for freedom, expanded liberty, defeated totalitarianism and terror.
#
# And built the strongest, freest, and most prosperous nation the world has ever known.
#
# Now is the hour.
#
# Our moment of responsibility.
#
# Our test of resolve and conscience, of history itself.
#
# It is in this moment that our character is formed. Our purpose is found. Our future is forged.
#
# Well I know this nation.
# =========
# FINAL ANSWER: The president did not mention Michael Jackson.
#
# QUESTION: What is the cure of Autism Spectrum Disorder?
# =========
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# research applic machin learn approach earli detect autism combin questionnair home video screen halim abbas,1 ford garberson,1 eric glover,2 denni p wall1,3,4 1cognoa inc. , palo alto , ca , usa www.linkedin.com/in/halimabba , 2eric_g @ ericglover.com , 3depart pediatr , stanford univers , stanford , ca , usa , 4depart biomed data scienc , stanford univers , stanford , ca , usa correspond : cognoa inc. , palo alto , ca , usa ; halim @ cognoa.com receiv 19 septemb 2017 ; revis 16 march 2018 ; editori decis
# Question: What is the cure of Autism Spectrum Disorder?
# Relevant text, if any:
# The research team at Cognoa Inc., led by Halim Abbas, Ford Garberson, Eric Glover, Denise P. Wall, and colleagues, is developing an approach to early detect autism using a combination of questionnaires, home videos, and machine learning algorithms. The team's work has been published in various scientific journals and presented at conferences. For more information, please contact Cognoa Inc. at [halim@cognoa.com](mailto:halim@cognoa.com).
#
# This text does not provide any information about the cure of Autism Spectrum Disorder. It only mentions that the team at Cognoa Inc. is working on early detection of autism using a combination of methods.
#
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# scienc foundat china ( . 61772375 ) independ research project school inform manag wuhan univers ( : 413100032 ) . current issu full text archiv journal avail emerald insight : http : //www.emerald.com/insight/0737-8831.htm receiv 31 august 2019 revis 16 decemb 2019 accept 23 januari 2020 librari hi tech © emerald publish limit 0737-8831 doi 10.1108/lht-08-2019-0176 basi commun interperson relationship other . abnorm express promin manifest autism , also one criterion diagnosi autism . doctor diagnos autism
# Question: What is the cure of Autism Spectrum Disorder?
# Relevant text, if any:
# The current issue of the Full Text Archive Journal of High Technology, available on Emerald Insight, contains a research project conducted by the Science Foundation of China and the School of Management at Wuhan University. The study investigates the role of interpersonal relationships in the diagnosis of autism, using abnormal expressions and prominent manifestations as criteria. The doctor diagnoses autism based on these findings. However, the text does not provide any information on the cure or treatment of Autism Spectrum Disorder.
# =========
# FINAL ANSWER: The text does not provide any information about the cure of Autism Spectrum Disorder. It only mentions research on early detection and diagnosis.

# %%
question = "What are Stereotypical and maladaptive behaviors in Autism Spectrum, how are these detected and managed?"
result = qa.run({"query": question})
print(result)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# generated_text Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# ouss et al . translat psychiatri ( 2020 ) 10:54 http : //doi.org/10.1038/s41398-020-0743-8 translat psychiatri r c l e p e n c c e behavior interact imag 9 month age predict autism/intellectu disabl high-risk infant west syndrom lisa ouss1 , giusepp palestra 2 , catherin saint-georges2,3 , marluc leitgel gille1 , moham afshar4 , hugu pellerin2 , kevin bailly2 , moham chetouani2 , laurenc robel1 , bernard golse1 , rima nabbout5 , isabel desguerre5 , mariana guergova-kuras4 david cohen 2,3 abstract autom
# Question: What are Stereotypical and maladaptive behaviors in Autism Spectrum, how are these detected and managed?
# Relevant text, if any:
# The present study aimed to investigate the relationship between 9-month-old behavior and the risk of developing autism spectrum disorder (ASD) or intellectual disability (ID) in high-risk infants with West Syndrome. The study used the Repetitive Behavior Scale-Revised (RBS-R) to assess stereotypical and maladaptive behaviors. The results showed that the total RBS-R score was significantly higher in the ASD/ID group compared to the control group. The RBS-R subscale scores for repetitive behaviors, self-injurious behavior, and hyperactivity/perseveration were also significantly higher in the ASD/ID group. These findings suggest that stereotypical and maladaptive behaviors, as measured by the RBS-R, can be detected in high-risk infants as early as 9 months of age and may predict the later development of ASD or ID.
# The Repetitive Behavior Scale-Revised (RBS-R) is a standardized measure used to assess stereotypical and maladaptive behaviors in individuals with autism spectrum disorder (ASD) and other developmental disabilities. The RBS-R consists of three subscales: repetitive behaviors, self-injurious behavior, and hyperactivity/perseveration. Stereotypical behaviors include repetitive motor mannerisms, such as hand or body posturing, and repetitive speech or language. Maladaptive behaviors include self-injurious behavior, such as head banging or biting, and hyperactivity/perseveration, such as excessive motor activity or fixation on objects.
# Detection of stereotypical and maladaptive behaviors in young children with ASD can be challenging, as these behaviors may not always be apparent during routine clinical assessments. Parents and caregivers may be the first to notice these behaviors and should report any concerns to healthcare providers. Standardized measures, such as the RBS-R, can be used to assess and monitor these behaviors over time.
# Management of stereotypical and maladaptive behaviors in children with ASD can involve a variety of approaches, including behavioral interventions, medication, and environmental modifications. Behavioral interventions, such as applied behavior analysis (ABA), can be effective in reducing stereotypical and maladaptive behaviors. Medications, such as selective serotonin reuptake inhibitors (SSRIs), can be used to reduce self-injurious behavior and hyperactivity/perseveration. Environmental modifications, such as providing a quiet and predictable environment, can help reduce sensory overload and reduce the occurrence of stereotypical and maladaptive behaviors.
# In summary, stereotypical and maladaptive behaviors are common in individuals with autism spectrum disorder and can be detected as early as 9 months of age using standardized measures such as the Repetitive Behavior Scale-Revised (RBS-R). Detection and management of these behaviors can be challenging, but approaches such as behavioral interventions, medication, and environmental modifications can be effective in reducing their occurrence and improving overall functioning.
# generated_text Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# d. p. machin learn approach earli detect autism combin questionnair home video screen . j. . med . informat assoc . ocy039 , 10.1093_jamia_ocy039/1/ocy039 ( 2018 ) . 14. cognoa , inc. 2390 el camino real st 220 , palo alto , ca 94306 http : //www.cognoa.com/ . 15. wall , d. p. , dalli , r. l. , luyster , r. , jung , j.-i . & deluca , t. f. use artifici intellig shorten behavior diagnosi autism . plo one , http : //doi.org/10.1371/journal.pone.0043855 . ( 2012 ) . 16. lord , c. et al . multisit studi clinic
# Question: What are Stereotypical and maladaptive behaviors in Autism Spectrum, how are these detected and managed?
# Relevant text, if any:
#
# The machine learning approach proposed by Ocy039 et al. (2018) for early detection of autism combines questionnaires and home video screenings. The study used a dataset of medical records from the Medical Informatics Association (MIMIC) and the University of California, San Francisco (UCSF) to develop a machine learning model for identifying autistic traits. The model was able to accurately classify children with autism from typically developing children based on their behavioral patterns.
#
# Cognoa, Inc. offers an online autism screening tool that uses artificial intelligence to analyze behavioral data from children. The tool can be used to shorten the diagnostic process and provide earlier intervention for children with autism.
#
# Wall et al. (2012) used artificial intelligence to analyze shortened behavioral data in the diagnosis of autism. They found that machine learning algorithms were effective in identifying autistic traits and could potentially be used as a diagnostic tool.
#
# Lord et al. (2012) conducted a multisite study to clinically validate the use of the Autism Diagnostic Observation Schedule, Second Edition (ADOS-2) as a diagnostic tool for autism. The study found that the ADOS-2 was effective in identifying autistic traits and could be used as a standardized diagnostic tool.
#
# Stereotypical and maladaptive behaviors are common in individuals with autism spectrum disorder (ASD). These behaviors can include repetitive movements, such as hand-flapping or rocking, and resistance to change in routine. They can also include self-injurious behavior, such as head-banging or biting.
#
# Early detection of autism is important for providing effective intervention and support for individuals with ASD. Machine learning approaches, such as those proposed by Ocy039 et al. (2018) and Wall et al. (2012), can be used to analyze behavioral data and identify autistic traits. Online screening tools, such as the one offered by Cognoa, Inc., can provide earlier intervention and support for children with autism. Standardized diagnostic tools, such as the ADOS-2, can be used to confirm a diagnosis of autism and guide intervention and support.
#
# In summary, stereotypical and maladaptive behaviors are common in individuals with autism spectrum disorder. Early detection of autism is important for providing effective intervention and support. Machine learning approaches, online screening tools, and standardized diagnostic tools can be used to identify autistic traits and provide earlier intervention and support for individuals with autism.
# num_tokens, token_max 3040 3000
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# generated_text Given the following extracted parts of a long document and a question, create a final answer.
# If you don't know the answer, just say that you don't know. Don't try to make up an answer.
#
# QUESTION: Which state/country's law governs the interpretation of the contract?
# =========
# Content: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.
#
# Content: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.
#
# 11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.
#
# 11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.
#
# 11.9 No Third-Party Beneficiaries.
#
# Content: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,
# =========
# FINAL ANSWER: This Agreement is governed by English law.
#
# QUESTION: What did the president say about Michael Jackson?
# =========
# Content: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.
#
# Last year COVID-19 kept us apart. This year we are finally together again.
#
# Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.
#
# With a duty to one another to the American people to the Constitution.
#
# And with an unwavering resolve that freedom will always triumph over tyranny.
#
# Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated.
#
# He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined.
#
# He met the Ukrainian people.
#
# From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world.
#
# Groups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.
#
# Content: And we won’t stop.
#
# We have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life.
#
# Let’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.
#
# Let’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.
#
# We can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together.
#
# I recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera.
#
# They were responding to a 9-1-1 call when a man shot and killed them with a stolen gun.
#
# Officer Mora was 27 years old.
#
# Officer Rivera was 22.
#
# Both Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers.
#
# I spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.
#
# Content: And a proud Ukrainian people, who have known 30 years  of independence, have repeatedly shown that they will not tolerate anyone who tries to take their country backwards.
#
# To all Americans, I will be honest with you, as I’ve always promised. A Russian dictator, invading a foreign country, has costs around the world.
#
# And I’m taking robust action to make sure the pain of our sanctions  is targeted at Russia’s economy. And I will use every tool at our disposal to protect American businesses and consumers.
#
# Tonight, I can announce that the United States has worked with 30 other countries to release 60 Million barrels of oil from reserves around the world.
#
# America will lead that effort, releasing 30 Million barrels from our own Strategic Petroleum Reserve. And we stand ready to do more if necessary, unified with our allies.
#
# These steps will help blunt gas prices here at home. And I know the news about what’s happening can seem alarming.
#
# But I want you to know that we are going to be okay.
#
# Content: More support for patients and families.
#
# To get there, I call on Congress to fund ARPA-H, the Advanced Research Projects Agency for Health.
#
# It’s based on DARPA—the Defense Department project that led to the Internet, GPS, and so much more.
#
# ARPA-H will have a singular purpose—to drive breakthroughs in cancer, Alzheimer’s, diabetes, and more.
#
# A unity agenda for the nation.
#
# We can do this.
#
# My fellow Americans—tonight , we have gathered in a sacred space—the citadel of our democracy.
#
# In this Capitol, generation after generation, Americans have debated great questions amid great strife, and have done great things.
#
# We have fought for freedom, expanded liberty, defeated totalitarianism and terror.
#
# And built the strongest, freest, and most prosperous nation the world has ever known.
#
# Now is the hour.
#
# Our moment of responsibility.
#
# Our test of resolve and conscience, of history itself.
#
# It is in this moment that our character is formed. Our purpose is found. Our future is forged.
#
# Well I know this nation.
# =========
# FINAL ANSWER: The president did not mention Michael Jackson.
#
# QUESTION: What are Stereotypical and maladaptive behaviors in Autism Spectrum, how are these detected and managed?
# =========
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# ouss et al . translat psychiatri ( 2020 ) 10:54 http : //doi.org/10.1038/s41398-020-0743-8 translat psychiatri r c l e p e n c c e behavior interact imag 9 month age predict autism/intellectu disabl high-risk infant west syndrom lisa ouss1 , giusepp palestra 2 , catherin saint-georges2,3 , marluc leitgel gille1 , moham afshar4 , hugu pellerin2 , kevin bailly2 , moham chetouani2 , laurenc robel1 , bernard golse1 , rima nabbout5 , isabel desguerre5 , mariana guergova-kuras4 david cohen 2,3 abstract autom
# Question: What are Stereotypical and maladaptive behaviors in Autism Spectrum, how are these detected and managed?
# Relevant text, if any:
# The present study aimed to investigate the relationship between 9-month-old behavior and the risk of developing autism spectrum disorder (ASD) or intellectual disability (ID) in high-risk infants with West Syndrome. The study used the Repetitive Behavior Scale-Revised (RBS-R) to assess stereotypical and maladaptive behaviors. The results showed that the total RBS-R score was significantly higher in the ASD/ID group compared to the control group. The RBS-R subscale scores for repetitive behaviors, self-injurious behavior, and hyperactivity/perseveration were also significantly higher in the ASD/ID group. These findings suggest that stereotypical and maladaptive behaviors, as measured by the RBS-R, can be detected in high-risk infants as early as 9 months of age and may predict the later development of ASD or ID.
# The Repetitive Behavior Scale-Revised (RBS-R) is a standardized measure used to assess stereotypical and maladaptive behaviors in individuals with autism spectrum disorder (ASD) and other developmental disabilities. The RBS-R consists of three subscales: repetitive behaviors, self-injurious behavior, and hyperactivity/perseveration. Stereotypical behaviors include repetitive motor mannerisms, such as hand or body posturing, and repetitive speech or language. Maladaptive behaviors include self-injurious behavior, such as head banging or biting, and hyperactivity/perseveration, such as excessive motor activity or fixation on objects.
# Detection of stereotypical and maladaptive behaviors in young children with ASD can be challenging, as these behaviors may not always be apparent during routine clinical assessments. Parents and caregivers may be the first to notice these behaviors and should report any concerns to healthcare providers. Standardized measures, such as the RBS-R, can be used to assess and monitor these behaviors over time.
# Management of stereotypical and maladaptive behaviors in children with ASD can involve a variety of approaches, including behavioral interventions, medication, and environmental modifications. Behavioral interventions, such as applied behavior analysis (ABA), can be effective in reducing stereotypical and maladaptive behaviors. Medications, such as selective serotonin reuptake inhibitors (SSRIs), can be used to reduce self-injurious behavior and hyperactivity/perseveration. Environmental modifications, such as providing a quiet and predictable environment, can help reduce sensory overload and reduce the occurrence of stereotypical and maladaptive behaviors.
# In summary, stereotypical and maladaptive behaviors are common in individuals with autism spectrum disorder and can be detected as early as 9 months of age using standardized measures such as the Repetitive Behavior Scale-Revised (RBS-R). Detection and management of these behaviors can be challenging, but approaches such as behavioral interventions, medication, and environmental modifications can be effective in reducing their occurrence and improving overall functioning.
# =========
# FINAL ANSWER: The text provides information on how stereotypical and maladaptive behaviors in Autism Spectrum can be detected and managed using the Repetitive Behavior Scale-Revised (RBS-R) and various approaches such as behavioral interventions, medication, and environmental modifications. The text also mentions that these behaviors can be detected as early as 9 months of age.
# generated_text Given the following extracted parts of a long document and a question, create a final answer.
# If you don't know the answer, just say that you don't know. Don't try to make up an answer.
#
# QUESTION: Which state/country's law governs the interpretation of the contract?
# =========
# Content: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.
#
# Content: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.
#
# 11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.
#
# 11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.
#
# 11.9 No Third-Party Beneficiaries.
#
# Content: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,
# =========
# FINAL ANSWER: This Agreement is governed by English law.
#
# QUESTION: What did the president say about Michael Jackson?
# =========
# Content: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.
#
# Last year COVID-19 kept us apart. This year we are finally together again.
#
# Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.
#
# With a duty to one another to the American people to the Constitution.
#
# And with an unwavering resolve that freedom will always triumph over tyranny.
#
# Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated.
#
# He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined.
#
# He met the Ukrainian people.
#
# From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world.
#
# Groups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.
#
# Content: And we won’t stop.
#
# We have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life.
#
# Let’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.
#
# Let’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.
#
# We can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together.
#
# I recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera.
#
# They were responding to a 9-1-1 call when a man shot and killed them with a stolen gun.
#
# Officer Mora was 27 years old.
#
# Officer Rivera was 22.
#
# Both Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers.
#
# I spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.
#
# Content: And a proud Ukrainian people, who have known 30 years  of independence, have repeatedly shown that they will not tolerate anyone who tries to take their country backwards.
#
# To all Americans, I will be honest with you, as I’ve always promised. A Russian dictator, invading a foreign country, has costs around the world.
#
# And I’m taking robust action to make sure the pain of our sanctions  is targeted at Russia’s economy. And I will use every tool at our disposal to protect American businesses and consumers.
#
# Tonight, I can announce that the United States has worked with 30 other countries to release 60 Million barrels of oil from reserves around the world.
#
# America will lead that effort, releasing 30 Million barrels from our own Strategic Petroleum Reserve. And we stand ready to do more if necessary, unified with our allies.
#
# These steps will help blunt gas prices here at home. And I know the news about what’s happening can seem alarming.
#
# But I want you to know that we are going to be okay.
#
# Content: More support for patients and families.
#
# To get there, I call on Congress to fund ARPA-H, the Advanced Research Projects Agency for Health.
#
# It’s based on DARPA—the Defense Department project that led to the Internet, GPS, and so much more.
#
# ARPA-H will have a singular purpose—to drive breakthroughs in cancer, Alzheimer’s, diabetes, and more.
#
# A unity agenda for the nation.
#
# We can do this.
#
# My fellow Americans—tonight , we have gathered in a sacred space—the citadel of our democracy.
#
# In this Capitol, generation after generation, Americans have debated great questions amid great strife, and have done great things.
#
# We have fought for freedom, expanded liberty, defeated totalitarianism and terror.
#
# And built the strongest, freest, and most prosperous nation the world has ever known.
#
# Now is the hour.
#
# Our moment of responsibility.
#
# Our test of resolve and conscience, of history itself.
#
# It is in this moment that our character is formed. Our purpose is found. Our future is forged.
#
# Well I know this nation.
# =========
# FINAL ANSWER: The president did not mention Michael Jackson.
#
# QUESTION: What are Stereotypical and maladaptive behaviors in Autism Spectrum, how are these detected and managed?
# =========
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# d. p. machin learn approach earli detect autism combin questionnair home video screen . j. . med . informat assoc . ocy039 , 10.1093_jamia_ocy039/1/ocy039 ( 2018 ) . 14. cognoa , inc. 2390 el camino real st 220 , palo alto , ca 94306 http : //www.cognoa.com/ . 15. wall , d. p. , dalli , r. l. , luyster , r. , jung , j.-i . & deluca , t. f. use artifici intellig shorten behavior diagnosi autism . plo one , http : //doi.org/10.1371/journal.pone.0043855 . ( 2012 ) . 16. lord , c. et al . multisit studi clinic
# Question: What are Stereotypical and maladaptive behaviors in Autism Spectrum, how are these detected and managed?
# Relevant text, if any:
#
# The machine learning approach proposed by Ocy039 et al. (2018) for early detection of autism combines questionnaires and home video screenings. The study used a dataset of medical records from the Medical Informatics Association (MIMIC) and the University of California, San Francisco (UCSF) to develop a machine learning model for identifying autistic traits. The model was able to accurately classify children with autism from typically developing children based on their behavioral patterns.
#
# Cognoa, Inc. offers an online autism screening tool that uses artificial intelligence to analyze behavioral data from children. The tool can be used to shorten the diagnostic process and provide earlier intervention for children with autism.
#
# Wall et al. (2012) used artificial intelligence to analyze shortened behavioral data in the diagnosis of autism. They found that machine learning algorithms were effective in identifying autistic traits and could potentially be used as a diagnostic tool.
#
# Lord et al. (2012) conducted a multisite study to clinically validate the use of the Autism Diagnostic Observation Schedule, Second Edition (ADOS-2) as a diagnostic tool for autism. The study found that the ADOS-2 was effective in identifying autistic traits and could be used as a standardized diagnostic tool.
#
# Stereotypical and maladaptive behaviors are common in individuals with autism spectrum disorder (ASD). These behaviors can include repetitive movements, such as hand-flapping or rocking, and resistance to change in routine. They can also include self-injurious behavior, such as head-banging or biting.
#
# Early detection of autism is important for providing effective intervention and support for individuals with ASD. Machine learning approaches, such as those proposed by Ocy039 et al. (2018) and Wall et al. (2012), can be used to analyze behavioral data and identify autistic traits. Online screening tools, such as the one offered by Cognoa, Inc., can provide earlier intervention and support for children with autism. Standardized diagnostic tools, such as the ADOS-2, can be used to confirm a diagnosis of autism and guide intervention and support.
#
# In summary, stereotypical and maladaptive behaviors are common in individuals with autism spectrum disorder. Early detection of autism is important for providing effective intervention and support. Machine learning approaches, online screening tools, and standardized diagnostic tools can be used to identify autistic traits and provide earlier intervention and support for individuals with autism.
# =========
# FINAL ANSWER: Stereotypical and maladaptive behaviors in Autism Spectrum include repetitive movements, resistance to change in routine, and self-injurious behavior. Early detection of autism is important for providing effective intervention and support. Machine learning approaches, online screening tools, and standardized diagnostic tools can be used to identify autistic traits and provide earlier intervention and support. The document provides examples of machine learning approaches and online screening tools that have been used for early detection of autism.
# num_tokens, token_max 3817 3000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-0bd364c06933> in <cell line: 2>()
#       1 question = "What are Stereotypical and maladaptive behaviors in Autism Spectrum, how are these detected and managed?"
# ----> 2 result = qa.run({"query": question})
#       3 print(result)
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     143                 warned = True
#     144                 emit_warning()
# --> 145             return wrapped(*args, **kwargs)
#     146
#     147         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     567             if len(args) != 1:
#     568                 raise ValueError("`run` supports only one positional argument.")
# --> 569             return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     570                 _output_key
#     571             ]
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     143                 warned = True
#     144                 emit_warning()
# --> 145             return wrapped(*args, **kwargs)
#     146
#     147         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     376         }
#     377
# --> 378         return self.invoke(
#     379             inputs,
#     380             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     161         except BaseException as e:
#     162             run_manager.on_chain_error(e)
# --> 163             raise e
#     164         run_manager.on_chain_end(outputs)
#     165
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     151             self._validate_inputs(inputs)
#     152             outputs = (
# --> 153                 self._call(inputs, run_manager=run_manager)
#     154                 if new_arg_supported
#     155                 else self._call(inputs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/retrieval_qa/base.py in _call(self, inputs, run_manager)
#     142         else:
#     143             docs = self._get_docs(question)  # type: ignore[call-arg]
# --> 144         answer = self.combine_documents_chain.run(
#     145             input_documents=docs, question=question, callbacks=_run_manager.get_child()
#     146         )
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     143                 warned = True
#     144                 emit_warning()
# --> 145             return wrapped(*args, **kwargs)
#     146
#     147         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     572
#     573         if kwargs and not args:
# --> 574             return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     575                 _output_key
#     576             ]
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     143                 warned = True
#     144                 emit_warning()
# --> 145             return wrapped(*args, **kwargs)
#     146
#     147         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     376         }
#     377
# --> 378         return self.invoke(
#     379             inputs,
#     380             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     161         except BaseException as e:
#     162             run_manager.on_chain_error(e)
# --> 163             raise e
#     164         run_manager.on_chain_end(outputs)
#     165
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     151             self._validate_inputs(inputs)
#     152             outputs = (
# --> 153                 self._call(inputs, run_manager=run_manager)
#     154                 if new_arg_supported
#     155                 else self._call(inputs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/combine_documents/base.py in _call(self, inputs, run_manager)
#     135         # Other keys are assumed to be needed for LLM prediction
#     136         other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# --> 137         output, extra_return_dict = self.combine_docs(
#     138             docs, callbacks=_run_manager.get_child(), **other_keys
#     139         )
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/combine_documents/map_reduce.py in combine_docs(self, docs, token_max, callbacks, **kwargs)
#     235             for i, r in enumerate(map_results)
#     236         ]
# --> 237         result, extra_return_dict = self.reduce_documents_chain.combine_docs(
#     238             result_docs, token_max=token_max, callbacks=callbacks, **kwargs
#     239         )
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/combine_documents/reduce.py in combine_docs(self, docs, token_max, callbacks, **kwargs)
#     242             element returned is a dictionary of other keys to return.
#     243         """
# --> 244         result_docs, extra_return_dict = self._collapse(
#     245             docs, token_max=token_max, callbacks=callbacks, **kwargs
#     246         )
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/combine_documents/reduce.py in _collapse(self, docs, token_max, callbacks, **kwargs)
#     297         retries: int = 0
#     298         while num_tokens is not None and num_tokens > _token_max:
# --> 299             new_result_doc_list = split_list_of_docs(
#     300                 result_docs, length_func, _token_max, **kwargs
#     301             )
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/combine_documents/reduce.py in split_list_of_docs(docs, length_func, token_max, **kwargs)
#      49             print("num_tokens, token_max", _num_tokens, token_max)
#      50             if len(_sub_result_docs) == 1:
# ---> 51                 raise ValueError(
#      52                     "A single document was longer than the context length,"
#      53                     " we cannot handle this."
#
# ValueError: A single document was longer than the context length, we cannot handle this.

# %%
question = "How relevant is eye contact and how it can be used to detect Autism?"
result = qa.run({"query": question})
print(result)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `run` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (2364 > 1024). Running this sequence through the model will result in indexing errors
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Given the following extracted parts of a long document and a question, create a final answer.
# If you don't know the answer, just say that you don't know. Don't try to make up an answer.
#
# QUESTION: Which state/country's law governs the interpretation of the contract?
# =========
# Content: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.
#
# Content: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.
#
# 11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.
#
# 11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.
#
# 11.9 No Third-Party Beneficiaries.
#
# Content: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,
# =========
# FINAL ANSWER: This Agreement is governed by English law.
#
# QUESTION: What did the president say about Michael Jackson?
# =========
# Content: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.
#
# Last year COVID-19 kept us apart. This year we are finally together again.
#
# Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.
#
# With a duty to one another to the American people to the Constitution.
#
# And with an unwavering resolve that freedom will always triumph over tyranny.
#
# Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated.
#
# He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined.
#
# He met the Ukrainian people.
#
# From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world.
#
# Groups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.
#
# Content: And we won’t stop.
#
# We have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life.
#
# Let’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.
#
# Let’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.
#
# We can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together.
#
# I recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera.
#
# They were responding to a 9-1-1 call when a man shot and killed them with a stolen gun.
#
# Officer Mora was 27 years old.
#
# Officer Rivera was 22.
#
# Both Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers.
#
# I spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.
#
# Content: And a proud Ukrainian people, who have known 30 years  of independence, have repeatedly shown that they will not tolerate anyone who tries to take their country backwards.
#
# To all Americans, I will be honest with you, as I’ve always promised. A Russian dictator, invading a foreign country, has costs around the world.
#
# And I’m taking robust action to make sure the pain of our sanctions  is targeted at Russia’s economy. And I will use every tool at our disposal to protect American businesses and consumers.
#
# Tonight, I can announce that the United States has worked with 30 other countries to release 60 Million barrels of oil from reserves around the world.
#
# America will lead that effort, releasing 30 Million barrels from our own Strategic Petroleum Reserve. And we stand ready to do more if necessary, unified with our allies.
#
# These steps will help blunt gas prices here at home. And I know the news about what’s happening can seem alarming.
#
# But I want you to know that we are going to be okay.
#
# Content: More support for patients and families.
#
# To get there, I call on Congress to fund ARPA-H, the Advanced Research Projects Agency for Health.
#
# It’s based on DARPA—the Defense Department project that led to the Internet, GPS, and so much more.
#
# ARPA-H will have a singular purpose—to drive breakthroughs in cancer, Alzheimer’s, diabetes, and more.
#
# A unity agenda for the nation.
#
# We can do this.
#
# My fellow Americans—tonight , we have gathered in a sacred space—the citadel of our democracy.
#
# In this Capitol, generation after generation, Americans have debated great questions amid great strife, and have done great things.
#
# We have fought for freedom, expanded liberty, defeated totalitarianism and terror.
#
# And built the strongest, freest, and most prosperous nation the world has ever known.
#
# Now is the hour.
#
# Our moment of responsibility.
#
# Our test of resolve and conscience, of history itself.
#
# It is in this moment that our character is formed. Our purpose is found. Our future is forged.
#
# Well I know this nation.
# =========
# FINAL ANSWER: The president did not mention Michael Jackson.
#
# QUESTION: How relevant is eye contact and how it can be used to detect Autism?
# =========
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# tic outcom autism spectrum disord : enhanc social com- munic sensori process use interact robot . j. psychiatr . re . 90 , 1–11 ( 2017 ) 25. chong , e. , chanda , k. , ye , z. , southerland , a. , ruiz , n. , jone , r.m. , rozga , a. , rehg , j.m . : detect gaze toward eye natur social interact use child ass . proc . acm interact . mob . wearabl ubiquit technol . 1 ( 3 ) , 43:1– 43:20 ( 2017 ) 26. ness , s.l. , manyakov , n.v. , bangert , a. , lewin , d. , jagannatha , s. , boic , m. , skalkin , a. ,
# Question: How relevant is eye contact and how it can be used to detect Autism?
# Relevant text, if any:
# 25. Chong et al. (2017) investigated the use of a robot to enhance social communication, sensori-motor processing, and interaction in children with autism spectrum disorders. They found that the robot's ability to detect and respond to gaze toward the eyes was an effective way to facilitate social interaction.
# 26. Ness et al. (2017) developed a system to detect gaze toward the eyes in natural social interactions using a child's assistance. They found that this method was effective in detecting gaze toward the eyes, which is an important aspect of social interaction for individuals with autism.
#
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# researchkit autism feasibl studi . npj digit medicin , 1 ( 1 ) , 20. http : //doi.org/10.1038/s41746-018-0024-6 ekman , p. ( 2003 ) . emot reveal ( 2nd ed. ) . new york , ny : time book . ekman , r. ( 1997 ) . face reveal : basic appli stud- i spontan express use facial action code system ( fac ) . new york , ny : oxford univers press . fillit , j. h. , longard , j. , lawrenc , m. a. , zwaigenbaum , l. , brian , j. , garon , n. , … bryson , s. e. ( 2015 ) . posit affect infant sibl child diagnos autism
# Question: How relevant is eye contact and how it can be used to detect Autism?
# Relevant text, if any:
# From the research article "Feasibility study of using the ResearchKit platform to screen for autism spectrum disorder in children" published in npj Digital Medicine, the authors mention that "The use of eye contact as a measure of social interaction has been suggested as a potential indicator of autism spectrum disorder (ASD) in children. However, the feasibility of using eye contact as a measure in a mobile application is not well established." (Ekman et al., 2018)
# In the book "Emotions Revealed: Recognizing Faces and Feelings from Darwin to the Present Day" by Paul Ekman, he discusses the Facial Action Coding System (FACS) and mentions that "Eye contact is a crucial component of social interaction and can reveal a great deal about a person's emotional state and intentions. In the context of autism, reduced eye contact is often observed and can be a diagnostic indicator." (Ekman, 2003)
# In the study "Positive Affect and Infant Sibling Risk for Autism Spectrum Disorder" published in the Journal of Autism and Developmental Disorders, the authors found that "Infants who later developed autism spectrum disorder (ASD) showed significantly less eye contact with their siblings during free play than did infants who did not develop ASD." (Fillit et al., 2015)
# Therefore, eye contact is a relevant indicator of autism spectrum disorder, and its feasibility as a measure in a mobile application is being explored. Reduced eye contact is often observed in individuals with autism and can be a diagnostic indicator.
# =========
# FINAL ANSWER: Eye contact is a relevant indicator of autism spectrum disorder, and its feasibility as a measure in a mobile application is being explored. Reduced eye contact is often observed in individuals with autism and can be a diagnostic indicator.

# %%
question = "How can cross country trials help in development of Machine learning based Multimodal solutions?"
result = qa.run({"query": question})
print(result)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Given the following extracted parts of a long document and a question, create a final answer.
# If you don't know the answer, just say that you don't know. Don't try to make up an answer.
#
# QUESTION: Which state/country's law governs the interpretation of the contract?
# =========
# Content: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.
#
# Content: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.
#
# 11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.
#
# 11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.
#
# 11.9 No Third-Party Beneficiaries.
#
# Content: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,
# =========
# FINAL ANSWER: This Agreement is governed by English law.
#
# QUESTION: What did the president say about Michael Jackson?
# =========
# Content: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.
#
# Last year COVID-19 kept us apart. This year we are finally together again.
#
# Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.
#
# With a duty to one another to the American people to the Constitution.
#
# And with an unwavering resolve that freedom will always triumph over tyranny.
#
# Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated.
#
# He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined.
#
# He met the Ukrainian people.
#
# From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world.
#
# Groups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.
#
# Content: And we won’t stop.
#
# We have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life.
#
# Let’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.
#
# Let’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.
#
# We can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together.
#
# I recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera.
#
# They were responding to a 9-1-1 call when a man shot and killed them with a stolen gun.
#
# Officer Mora was 27 years old.
#
# Officer Rivera was 22.
#
# Both Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers.
#
# I spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.
#
# Content: And a proud Ukrainian people, who have known 30 years  of independence, have repeatedly shown that they will not tolerate anyone who tries to take their country backwards.
#
# To all Americans, I will be honest with you, as I’ve always promised. A Russian dictator, invading a foreign country, has costs around the world.
#
# And I’m taking robust action to make sure the pain of our sanctions  is targeted at Russia’s economy. And I will use every tool at our disposal to protect American businesses and consumers.
#
# Tonight, I can announce that the United States has worked with 30 other countries to release 60 Million barrels of oil from reserves around the world.
#
# America will lead that effort, releasing 30 Million barrels from our own Strategic Petroleum Reserve. And we stand ready to do more if necessary, unified with our allies.
#
# These steps will help blunt gas prices here at home. And I know the news about what’s happening can seem alarming.
#
# But I want you to know that we are going to be okay.
#
# Content: More support for patients and families.
#
# To get there, I call on Congress to fund ARPA-H, the Advanced Research Projects Agency for Health.
#
# It’s based on DARPA—the Defense Department project that led to the Internet, GPS, and so much more.
#
# ARPA-H will have a singular purpose—to drive breakthroughs in cancer, Alzheimer’s, diabetes, and more.
#
# A unity agenda for the nation.
#
# We can do this.
#
# My fellow Americans—tonight , we have gathered in a sacred space—the citadel of our democracy.
#
# In this Capitol, generation after generation, Americans have debated great questions amid great strife, and have done great things.
#
# We have fought for freedom, expanded liberty, defeated totalitarianism and terror.
#
# And built the strongest, freest, and most prosperous nation the world has ever known.
#
# Now is the hour.
#
# Our moment of responsibility.
#
# Our test of resolve and conscience, of history itself.
#
# It is in this moment that our character is formed. Our purpose is found. Our future is forged.
#
# Well I know this nation.
# =========
# FINAL ANSWER: The president did not mention Michael Jackson.
#
# QUESTION: How can cross country trials help in development of Machine learning based Multimodal solutions?
# =========
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# identifi viabl method ( ) crowdsourc- ing video acquisit featur tag . addit , prospect trial undiagnos larger , more-balanc cohort includ exampl child non-aut development delay need better understand approach ’ potenti use autism diagnosi . support inform s1 tabl . result 8 classifi independ valid set . lr10 , lr5 , adtree7 top-3 best-perform classifi valid set , fall line result observ test dataset 162 video use earlier . lr5 still perform high- est specif 8 model . adtree7 , 7-featur altern decis tree ;
# Question: How can cross country trials help in development of Machine learning based Multimodal solutions?
# Relevant text, if any:
# The results of 8 classifi models are presented, with lr10, lr5, and adtree7 being the top-3 best-performing classifiers in the valid set. The fall line result observes that the test dataset of 162 videos uses earlier methods, and lr5 still performs with high specificity in the 8 model. The adtree7 and 7-featur altern decis tree are also mentioned as potential methods for autism diagnosis.
#
# Answer: The results of various machine learning models, including lr10, lr5, and adtree7, are presented, with lr5 having high specificity in the valid set. The test dataset of 162 videos uses earlier methods, and adtree7 and 7-featur altern decis tree are also mentioned as potential methods for autism diagnosis. Cross-country trials may help in the development of machine learning based multimodal solutions by providing a larger, more balanced cohort for inclusion, and by allowing for the comparison and evaluation of different methods and models. The use of earlier methods in the test dataset highlights the need for better understanding of the approach and potential improvements.
#
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# copyright holder . view copi licens , visit http : //creativecommons.org/licenses/by/4.0/ . correspond : lisa ouss ( lisa.ouss @ aphp.fr ) david cohen ( david.cohen @ aphp.fr ) 1servic de psychiatri de l ’ enfant , ap-hp , hôpital necker , 149 rue de sèvre , 75015 pari , franc 2institut de systèm intellig et de robotiqu , cnr , umr 7222 , sorbonn université , 4 place jussieu , 75252 pari cedex , franc full list author inform avail end articl 1234567890 ( ) : , ; 1234567890 ( ) : , ; 1234567890 ( ) : , ;
# Question: How can cross country trials help in development of Machine learning based Multimodal solutions?
# Relevant text, if any:
# There is a growing interest in using machine learning techniques in various fields, including healthcare and mental health. Cross-country trials can provide valuable data for the development of machine learning-based multimodal solutions. By collecting data from different populations and environments, researchers can improve the robustness and generalizability of their models. Additionally, cross-country trials can help identify potential biases and variations in data that may need to be addressed to ensure accurate and fair representation of different populations. Furthermore, collaborating with researchers and institutions in different countries can lead to new insights and innovations in the field of machine learning and multimodal solutions.
# Therefore, cross-country trials can play a crucial role in the development of machine learning-based multimodal solutions by providing diverse data and promoting international collaboration.
# Answer: Cross-country trials can help in the development of Machine learning based Multimodal solutions by providing diverse data and promoting international collaboration. This can improve the robustness and generalizability of models, help identify potential biases and variations in data, and lead to new insights and innovations in the field of Machine learning and multimodal solutions.
# =========
# FINAL ANSWER: Cross-country trials can help in the development of Machine learning based Multimodal solutions by providing diverse data and promoting international collaboration. This can improve the robustness and generalizability of models, help identify potential biases and variations in data, and lead to new insights and innovations in the field of Machine learning and multimodal solutions.

# %%
question = "How early infants cry can help in the early detection of Autism?"
result = qa.run({"query": question})
print(result)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Given the following extracted parts of a long document and a question, create a final answer.
# If you don't know the answer, just say that you don't know. Don't try to make up an answer.
#
# QUESTION: Which state/country's law governs the interpretation of the contract?
# =========
# Content: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.
#
# Content: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.
#
# 11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.
#
# 11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.
#
# 11.9 No Third-Party Beneficiaries.
#
# Content: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,
# =========
# FINAL ANSWER: This Agreement is governed by English law.
#
# QUESTION: What did the president say about Michael Jackson?
# =========
# Content: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.
#
# Last year COVID-19 kept us apart. This year we are finally together again.
#
# Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.
#
# With a duty to one another to the American people to the Constitution.
#
# And with an unwavering resolve that freedom will always triumph over tyranny.
#
# Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated.
#
# He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined.
#
# He met the Ukrainian people.
#
# From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world.
#
# Groups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.
#
# Content: And we won’t stop.
#
# We have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life.
#
# Let’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.
#
# Let’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.
#
# We can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together.
#
# I recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera.
#
# They were responding to a 9-1-1 call when a man shot and killed them with a stolen gun.
#
# Officer Mora was 27 years old.
#
# Officer Rivera was 22.
#
# Both Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers.
#
# I spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.
#
# Content: And a proud Ukrainian people, who have known 30 years  of independence, have repeatedly shown that they will not tolerate anyone who tries to take their country backwards.
#
# To all Americans, I will be honest with you, as I’ve always promised. A Russian dictator, invading a foreign country, has costs around the world.
#
# And I’m taking robust action to make sure the pain of our sanctions  is targeted at Russia’s economy. And I will use every tool at our disposal to protect American businesses and consumers.
#
# Tonight, I can announce that the United States has worked with 30 other countries to release 60 Million barrels of oil from reserves around the world.
#
# America will lead that effort, releasing 30 Million barrels from our own Strategic Petroleum Reserve. And we stand ready to do more if necessary, unified with our allies.
#
# These steps will help blunt gas prices here at home. And I know the news about what’s happening can seem alarming.
#
# But I want you to know that we are going to be okay.
#
# Content: More support for patients and families.
#
# To get there, I call on Congress to fund ARPA-H, the Advanced Research Projects Agency for Health.
#
# It’s based on DARPA—the Defense Department project that led to the Internet, GPS, and so much more.
#
# ARPA-H will have a singular purpose—to drive breakthroughs in cancer, Alzheimer’s, diabetes, and more.
#
# A unity agenda for the nation.
#
# We can do this.
#
# My fellow Americans—tonight , we have gathered in a sacred space—the citadel of our democracy.
#
# In this Capitol, generation after generation, Americans have debated great questions amid great strife, and have done great things.
#
# We have fought for freedom, expanded liberty, defeated totalitarianism and terror.
#
# And built the strongest, freest, and most prosperous nation the world has ever known.
#
# Now is the hour.
#
# Our moment of responsibility.
#
# Our test of resolve and conscience, of history itself.
#
# It is in this moment that our character is formed. Our purpose is found. Our future is forged.
#
# Well I know this nation.
# =========
# FINAL ANSWER: The president did not mention Michael Jackson.
#
# QUESTION: How early infants cry can help in the early detection of Autism?
# =========
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# toddler : initi studi investig earli detect autism pervas development disord . j autism dev disord . ( 2001 ) 31:131–44 . doi : 10.1023/a:1010738829569 23. legerste , markova g. intent make diﬀer : infant respons still-fac modiﬁ still-fac condit . infant behav dev . ( 2007 ) 30:232– 50. doi : 10.1016/j.infbeh.2007.02.008 24. yato , kawai , negayama k , sogon , tomiwa k , yamamoto h. infant respons matern still-fac 4 9 month . infant behav dev . ( 2008 ) 31:570–7 . doi : 10.1016/j.infbeh.2008.07.008 25.
# Question: How early infants cry can help in the early detection of Autism?
# Relevant text, if any:
# 20. toddler : initi studi investig earli detect autism pervas development disord. j autism dev disord. ( 2001 ) 31:131–44. doi : 10.1023/a:1010738829569
# This study investigates the early detection of autism and pervasive developmental disorders using the cry behavior of toddlers. The researchers found that infants with autism showed distinct cry patterns compared to typically developing infants. These findings suggest that cry analysis may be a useful tool in the early identification of autism.
#
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# develop . soc . cogn . affect neurosci . 9 , 538–543 ( 2014 ) . 40. jone , w. & klin , a. attent eye present declin 2-6-month- old infant later diagnos autism . natur 504 , 427–431 ( 2013 ) . 41. paul , r. , fuerst , y. , ramsay , g. , chawarska , k. & klin , a. mouth babe : vocal product infant sibl child asd . j. child psychol . psychiatri 52 , 588–598 ( 2011 ) . 42. sheinkopf , s. j. , iverson , j. m. , rinaldi , m. l. & lester , b. m. atyp cri acoust 6-month-old infant risk autism spectrum disord .
# Question: How early infants cry can help in the early detection of Autism?
# Relevant text, if any:
# The study by Jons et al. (2013) found that 2-6-month-old infants who later received a diagnosis of autism had a decreased attention to eye contact during a standardized test compared to typically developing infants. Paul et al. (2011) found that vocalizations produced by 6-month-old infants at risk for autism spectrum disorders were less varied and less socially engaging than those produced by typically developing infants. Sheinkopf et al. (2014) also found that atypical cry acoustics in 6-month-old infants were associated with an increased risk for autism spectrum disorders. These studies suggest that early differences in attention, vocalizations, and cry acoustics may be useful markers for identifying infants at risk for autism spectrum disorders.
# Therefore, the early cry of an infant can potentially help in the early detection of Autism as studies have shown that atypical cry acoustics in 6-month-old infants are associated with an increased risk for autism spectrum disorders.
# =========
# FINAL ANSWER: Yes, the early cry of an infant can potentially help in the early detection of Autism. Studies have shown that atypical cry acoustics in 6-month-old infants are associated with an increased risk for autism spectrum disorders.

# %%
question = "What are various methods to detect  Atypical Pattern of Facial expression in Children?"
result = qa.run({"query": question})
print(result)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Given the following extracted parts of a long document and a question, create a final answer.
# If you don't know the answer, just say that you don't know. Don't try to make up an answer.
#
# QUESTION: Which state/country's law governs the interpretation of the contract?
# =========
# Content: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.
#
# Content: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.
#
# 11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.
#
# 11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.
#
# 11.9 No Third-Party Beneficiaries.
#
# Content: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,
# =========
# FINAL ANSWER: This Agreement is governed by English law.
#
# QUESTION: What did the president say about Michael Jackson?
# =========
# Content: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.
#
# Last year COVID-19 kept us apart. This year we are finally together again.
#
# Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.
#
# With a duty to one another to the American people to the Constitution.
#
# And with an unwavering resolve that freedom will always triumph over tyranny.
#
# Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated.
#
# He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined.
#
# He met the Ukrainian people.
#
# From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world.
#
# Groups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.
#
# Content: And we won’t stop.
#
# We have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life.
#
# Let’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.
#
# Let’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.
#
# We can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together.
#
# I recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera.
#
# They were responding to a 9-1-1 call when a man shot and killed them with a stolen gun.
#
# Officer Mora was 27 years old.
#
# Officer Rivera was 22.
#
# Both Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers.
#
# I spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.
#
# Content: And a proud Ukrainian people, who have known 30 years  of independence, have repeatedly shown that they will not tolerate anyone who tries to take their country backwards.
#
# To all Americans, I will be honest with you, as I’ve always promised. A Russian dictator, invading a foreign country, has costs around the world.
#
# And I’m taking robust action to make sure the pain of our sanctions  is targeted at Russia’s economy. And I will use every tool at our disposal to protect American businesses and consumers.
#
# Tonight, I can announce that the United States has worked with 30 other countries to release 60 Million barrels of oil from reserves around the world.
#
# America will lead that effort, releasing 30 Million barrels from our own Strategic Petroleum Reserve. And we stand ready to do more if necessary, unified with our allies.
#
# These steps will help blunt gas prices here at home. And I know the news about what’s happening can seem alarming.
#
# But I want you to know that we are going to be okay.
#
# Content: More support for patients and families.
#
# To get there, I call on Congress to fund ARPA-H, the Advanced Research Projects Agency for Health.
#
# It’s based on DARPA—the Defense Department project that led to the Internet, GPS, and so much more.
#
# ARPA-H will have a singular purpose—to drive breakthroughs in cancer, Alzheimer’s, diabetes, and more.
#
# A unity agenda for the nation.
#
# We can do this.
#
# My fellow Americans—tonight , we have gathered in a sacred space—the citadel of our democracy.
#
# In this Capitol, generation after generation, Americans have debated great questions amid great strife, and have done great things.
#
# We have fought for freedom, expanded liberty, defeated totalitarianism and terror.
#
# And built the strongest, freest, and most prosperous nation the world has ever known.
#
# Now is the hour.
#
# Our moment of responsibility.
#
# Our test of resolve and conscience, of history itself.
#
# It is in this moment that our character is formed. Our purpose is found. Our future is forged.
#
# Well I know this nation.
# =========
# FINAL ANSWER: The president did not mention Michael Jackson.
#
# QUESTION: What are various methods to detect  Atypical Pattern of Facial expression in Children?
# =========
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# researchkit autism feasibl studi . npj digit medicin , 1 ( 1 ) , 20. http : //doi.org/10.1038/s41746-018-0024-6 ekman , p. ( 2003 ) . emot reveal ( 2nd ed. ) . new york , ny : time book . ekman , r. ( 1997 ) . face reveal : basic appli stud- i spontan express use facial action code system ( fac ) . new york , ny : oxford univers press . fillit , j. h. , longard , j. , lawrenc , m. a. , zwaigenbaum , l. , brian , j. , garon , n. , … bryson , s. e. ( 2015 ) . posit affect infant sibl child diagnos autism
# Question: What are various methods to detect  Atypical Pattern of Facial expression in Children?
# Relevant text, if any:
# The study by Fillit et al. (2015) investigated the use of the Facial Action Coding System (FACS) to detect atypical patterns of facial expression in children with autism. The researchers found that children with autism showed significantly different facial expressions compared to typically developing children in response to emotional stimuli. Specifically, they found that children with autism had reduced intensity and duration of facial expressions, as well as abnormal facial configurations.
# Ekman (1997) and Ekman (2003) provide a comprehensive overview of facial expression and its relevance to emotion recognition. They describe the Facial Action Coding System (FACS) as a standardized method for analyzing facial movements and expressions. This system allows for the identification of specific facial actions and configurations, which can be useful in detecting atypical patterns of facial expression in individuals with autism.
# Therefore, the use of the Facial Action Coding System (FACS) is a valid method to detect atypical patterns of facial expression in children with autism. Other methods, such as analyzing the intensity and duration of facial expressions, as well as examining abnormal facial configurations, may also be useful in this regard.
#
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# speciﬁc point throughout movi identiﬁ reliabl differenti child without asd base pattern facial movement express ( area curv individu movi rang 0.62 0.73 ) . instanc , child asd frequent display neutral express compar child without asd , express . frequenc express driven non-asd child often display rais eye- brow open mouth , characterist engagement/interest . preliminari result suggest comput code facial movement express via tablet-bas ass detect differ affect express , one earli , core featur asd . autism
# Question: What are various methods to detect  Atypical Pattern of Facial expression in Children?
# Relevant text, if any:
# The study focuses on identifying a specific point throughout movie clips to differentiate a child with Autism Spectrum Disorder (ASD) from a child without ASD based on facial movement expressions. The area of curvature and individual movement range of 0.62 to 0.73 are used to identify the child with ASD. The child with ASD frequently displays neutral expressions compared to a child without ASD, and the frequency of expressive movements is driven by non-ASD children. The preliminary results suggest that a computational code for facial movement expression via tablet-based assessment can detect differences in affect expression, one early indicator of ASD. The study identifies core features of ASD, including frequent display of raised eye-brows and open mouth, as characteristically indicative of engagement/interest. The study also mentions the use of autism as a keyword.
# =========
# FINAL ANSWER: The methods mentioned in the text to detect atypical patterns of facial expression in children with Autism Spectrum Disorder (ASD) include:
#
# 1. Using a specific point throughout movie clips to differentiate a child with ASD from a child without ASD based on facial movement expressions. The area of curvature and individual movement range of 0.62 to 0.73 are used to identify the child with ASD.
# 2. Frequently displaying neutral expressions compared to a child without ASD.
# 3. Using a computational code for facial movement expression via tablet-based assessment to detect differences in affect expression.
# 4. Identifying core features of ASD, including frequent display of raised eye-brows and open mouth, as characteristically indicative of engagement/interest.
#
# The text also mentions the use of the Facial Action Coding System (FACS) and analyzing the intensity and duration of facial expressions, as well as examining abnormal facial configurations, as useful methods to detect atypical patterns of facial expression in children with autism. However, these methods were not explicitly mentioned in the provided text.

# %%
question = "What kind of facial expressions can be used to detect Autism Disorder in children?"
result = qa.run({"query": question})
print(result)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Given the following extracted parts of a long document and a question, create a final answer.
# If you don't know the answer, just say that you don't know. Don't try to make up an answer.
#
# QUESTION: Which state/country's law governs the interpretation of the contract?
# =========
# Content: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.
#
# Content: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.
#
# 11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.
#
# 11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.
#
# 11.9 No Third-Party Beneficiaries.
#
# Content: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,
# =========
# FINAL ANSWER: This Agreement is governed by English law.
#
# QUESTION: What did the president say about Michael Jackson?
# =========
# Content: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.
#
# Last year COVID-19 kept us apart. This year we are finally together again.
#
# Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.
#
# With a duty to one another to the American people to the Constitution.
#
# And with an unwavering resolve that freedom will always triumph over tyranny.
#
# Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated.
#
# He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined.
#
# He met the Ukrainian people.
#
# From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world.
#
# Groups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.
#
# Content: And we won’t stop.
#
# We have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life.
#
# Let’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.
#
# Let’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.
#
# We can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together.
#
# I recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera.
#
# They were responding to a 9-1-1 call when a man shot and killed them with a stolen gun.
#
# Officer Mora was 27 years old.
#
# Officer Rivera was 22.
#
# Both Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers.
#
# I spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.
#
# Content: And a proud Ukrainian people, who have known 30 years  of independence, have repeatedly shown that they will not tolerate anyone who tries to take their country backwards.
#
# To all Americans, I will be honest with you, as I’ve always promised. A Russian dictator, invading a foreign country, has costs around the world.
#
# And I’m taking robust action to make sure the pain of our sanctions  is targeted at Russia’s economy. And I will use every tool at our disposal to protect American businesses and consumers.
#
# Tonight, I can announce that the United States has worked with 30 other countries to release 60 Million barrels of oil from reserves around the world.
#
# America will lead that effort, releasing 30 Million barrels from our own Strategic Petroleum Reserve. And we stand ready to do more if necessary, unified with our allies.
#
# These steps will help blunt gas prices here at home. And I know the news about what’s happening can seem alarming.
#
# But I want you to know that we are going to be okay.
#
# Content: More support for patients and families.
#
# To get there, I call on Congress to fund ARPA-H, the Advanced Research Projects Agency for Health.
#
# It’s based on DARPA—the Defense Department project that led to the Internet, GPS, and so much more.
#
# ARPA-H will have a singular purpose—to drive breakthroughs in cancer, Alzheimer’s, diabetes, and more.
#
# A unity agenda for the nation.
#
# We can do this.
#
# My fellow Americans—tonight , we have gathered in a sacred space—the citadel of our democracy.
#
# In this Capitol, generation after generation, Americans have debated great questions amid great strife, and have done great things.
#
# We have fought for freedom, expanded liberty, defeated totalitarianism and terror.
#
# And built the strongest, freest, and most prosperous nation the world has ever known.
#
# Now is the hour.
#
# Our moment of responsibility.
#
# Our test of resolve and conscience, of history itself.
#
# It is in this moment that our character is formed. Our purpose is found. Our future is forged.
#
# Well I know this nation.
# =========
# FINAL ANSWER: The president did not mention Michael Jackson.
#
# QUESTION: What kind of facial expressions can be used to detect Autism Disorder in children?
# =========
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# researchkit autism feasibl studi . npj digit medicin , 1 ( 1 ) , 20. http : //doi.org/10.1038/s41746-018-0024-6 ekman , p. ( 2003 ) . emot reveal ( 2nd ed. ) . new york , ny : time book . ekman , r. ( 1997 ) . face reveal : basic appli stud- i spontan express use facial action code system ( fac ) . new york , ny : oxford univers press . fillit , j. h. , longard , j. , lawrenc , m. a. , zwaigenbaum , l. , brian , j. , garon , n. , … bryson , s. e. ( 2015 ) . posit affect infant sibl child diagnos autism
# Question: What kind of facial expressions can be used to detect Autism Disorder in children?
# Relevant text, if any:
# The use of facial expressions in the diagnosis of autism has been explored in various studies. One such study published in the journal npj Digital Medicine in 2018 investigated the feasibility of using ResearchKit, an open-source software framework for mobile health research, to collect and analyze facial expressions in children with autism. The study found that machine learning algorithms could accurately distinguish between children with autism and typically developing children based on their facial expressions.
# Another study, published in the book "Emotions Revealed" by Paul Ekman, discusses the Facial Action Coding System (FACS), which is a standardized system for analyzing facial expressions. The authors of a 2015 study published in the Journal of Autism and Developmental Disorders used FACS to analyze facial expressions in children with autism and their siblings. They found that children with autism showed fewer and less intense facial expressions compared to their typically developing siblings.
# Therefore, reduced and less intense facial expressions can be used as indicators for detecting Autism Disorder in children. However, it is important to note that facial expressions should not be the sole basis for diagnosis and should be used in conjunction with other diagnostic tools and assessments.
#
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# ” , nch data brief , vol . 291 , pp . 1-8. correspond author wang zhao contact : creativesoft @ sohu.com instruct order reprint articl , plea visit websit : www.emeraldgrouppublishing.com/licensing/reprints.htm contact u detail : permiss @ emeraldinsight.com facial express autism diagnosi
# Question: What kind of facial expressions can be used to detect Autism Disorder in children?
# Relevant text, if any:
# The present study aimed to investigate the facial expressions of children with autism spectrum disorder (ASD) and typical development (TD) during a social interaction task. The results showed that children with ASD displayed fewer facial expressions overall, and their expressions were less variable and less socially appropriate than those of children with TD. Specifically, children with ASD showed fewer smiles, more frowns, and more neutral expressions than children with TD. These findings suggest that the analysis of facial expressions may be a useful tool in the early diagnosis of ASD.
# Therefore, children with Autism Disorder may display fewer smiles, more frowns, and more neutral expressions than children with typical development.
# =========
# FINAL ANSWER: Children with Autism Disorder may display fewer smiles, more frowns, and more neutral expressions than children with typical development.

# %%
question = "What are methods to detect Autism from home videos?"
result = qa.run({"query": question})
print(result)
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.10/logging/__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.10/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelapp.py", line 619, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.10/dist-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 685, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 738, in _run_callback
#     ret = callback()
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 825, in inner
#     self.ctx_run(self.run)
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 786, in run
#     yielded = self.gen.send(value)
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 361, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 539, in execute_request
#     self.do_execute(
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-22-e0a5e4942e97>", line 2, in <cell line: 2>
#     result = qa.run({"query": question})
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py", line 145, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/base.py", line 569, in run
#     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py", line 145, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/base.py", line 378, in __call__
#     return self.invoke(
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/base.py", line 153, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/retrieval_qa/base.py", line 144, in _call
#     answer = self.combine_documents_chain.run(
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py", line 145, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/base.py", line 574, in run
#     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py", line 145, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/base.py", line 378, in __call__
#     return self.invoke(
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/base.py", line 153, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/combine_documents/base.py", line 137, in _call
#     output, extra_return_dict = self.combine_docs(
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/combine_documents/map_reduce.py", line 226, in combine_docs
#     map_results = self.llm_chain.apply(
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py", line 224, in apply
#     response = self.generate(input_list, run_manager=run_manager)
#   File "/usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py", line 115, in generate
#     return self.llm.generate_prompt(
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/llms.py", line 597, in generate_prompt
#     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/llms.py", line 767, in generate
#     output = self._generate_helper(
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/llms.py", line 621, in _generate_helper
#     self._generate(
#   File "/usr/local/lib/python3.10/dist-packages/langchain_community/llms/huggingface_pipeline.py", line 267, in _generate
#     responses = self.pipeline(
#   File "/usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_generation.py", line 240, in __call__
#     return super().__call__(text_inputs, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py", line 1167, in __call__
#     logger.warning_once(
#   File "/usr/local/lib/python3.10/dist-packages/transformers/utils/logging.py", line 329, in warning_once
#     self.warning(*args, **kwargs)
# Message: 'You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset'
# Arguments: (<class 'UserWarning'>,)
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Given the following extracted parts of a long document and a question, create a final answer.
# If you don't know the answer, just say that you don't know. Don't try to make up an answer.
#
# QUESTION: Which state/country's law governs the interpretation of the contract?
# =========
# Content: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.
#
# Content: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.
#
# 11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.
#
# 11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.
#
# 11.9 No Third-Party Beneficiaries.
#
# Content: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,
# =========
# FINAL ANSWER: This Agreement is governed by English law.
#
# QUESTION: What did the president say about Michael Jackson?
# =========
# Content: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.
#
# Last year COVID-19 kept us apart. This year we are finally together again.
#
# Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.
#
# With a duty to one another to the American people to the Constitution.
#
# And with an unwavering resolve that freedom will always triumph over tyranny.
#
# Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated.
#
# He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined.
#
# He met the Ukrainian people.
#
# From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world.
#
# Groups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.
#
# Content: And we won’t stop.
#
# We have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life.
#
# Let’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.
#
# Let’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.
#
# We can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together.
#
# I recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera.
#
# They were responding to a 9-1-1 call when a man shot and killed them with a stolen gun.
#
# Officer Mora was 27 years old.
#
# Officer Rivera was 22.
#
# Both Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers.
#
# I spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.
#
# Content: And a proud Ukrainian people, who have known 30 years  of independence, have repeatedly shown that they will not tolerate anyone who tries to take their country backwards.
#
# To all Americans, I will be honest with you, as I’ve always promised. A Russian dictator, invading a foreign country, has costs around the world.
#
# And I’m taking robust action to make sure the pain of our sanctions  is targeted at Russia’s economy. And I will use every tool at our disposal to protect American businesses and consumers.
#
# Tonight, I can announce that the United States has worked with 30 other countries to release 60 Million barrels of oil from reserves around the world.
#
# America will lead that effort, releasing 30 Million barrels from our own Strategic Petroleum Reserve. And we stand ready to do more if necessary, unified with our allies.
#
# These steps will help blunt gas prices here at home. And I know the news about what’s happening can seem alarming.
#
# But I want you to know that we are going to be okay.
#
# Content: More support for patients and families.
#
# To get there, I call on Congress to fund ARPA-H, the Advanced Research Projects Agency for Health.
#
# It’s based on DARPA—the Defense Department project that led to the Internet, GPS, and so much more.
#
# ARPA-H will have a singular purpose—to drive breakthroughs in cancer, Alzheimer’s, diabetes, and more.
#
# A unity agenda for the nation.
#
# We can do this.
#
# My fellow Americans—tonight , we have gathered in a sacred space—the citadel of our democracy.
#
# In this Capitol, generation after generation, Americans have debated great questions amid great strife, and have done great things.
#
# We have fought for freedom, expanded liberty, defeated totalitarianism and terror.
#
# And built the strongest, freest, and most prosperous nation the world has ever known.
#
# Now is the hour.
#
# Our moment of responsibility.
#
# Our test of resolve and conscience, of history itself.
#
# It is in this moment that our character is formed. Our purpose is found. Our future is forged.
#
# Well I know this nation.
# =========
# FINAL ANSWER: The president did not mention Michael Jackson.
#
# QUESTION: What are methods to detect Autism from home videos?
# =========
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# research articl mobil detect autism machin learn home video : develop prospect valid studi qandeel tariqid1,2 , jena danielsid1,2 , jessey nicol schwartzid1,2 , peter washingtonid1,2 , haik kalantarian1,2 , denni paul wallid1,2 * 1 depart pediatr , divis system medicin , stanford univers , california , unit state america , 2 depart biomed data scienc , stanford univers , california , unit state america * dpwall @ stanford.edu abstract background standard approach diagnos autism spectrum disord ( asd ) evalu
# Question: What are methods to detect Autism from home videos?
# Relevant text, if any:
# The use of machine learning algorithms in analyzing home videos for the early detection of autism spectrum disorder (ASD) has gained significant attention in recent years. In this study, we propose a method for developing a prospective, validated machine learning model for the detection of ASD from home videos. Our approach involves the following steps: (1) data collection and preprocessing, (2) feature extraction, (3) model selection and training, and (4) model validation and evaluation. We used a dataset of home videos of children with and without ASD, and applied various machine learning algorithms to identify features that distinguish between the two groups. Our results showed that a random forest classifier achieved high accuracy in distinguishing between the two groups, with an area under the receiver operating characteristic curve (AUC-ROC) of 0.87. These findings suggest that machine learning algorithms can be effective in detecting ASD from home videos, and provide a promising avenue for early intervention and diagnosis.
#
# Answer: The methods to detect Autism from home videos involve data collection and preprocessing, feature extraction, model selection and training, and model validation and evaluation using machine learning algorithms. The study proposes a prospective, validated machine learning model for the detection of Autism Spectrum Disorder (ASD) from home videos. The results showed that a random forest classifier achieved high accuracy in distinguishing between children with and without ASD, with an area under the receiver operating characteristic curve (AUC-ROC) of 0.87.
#
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# research applic machin learn approach earli detect autism combin questionnair home video screen halim abbas,1 ford garberson,1 eric glover,2 denni p wall1,3,4 1cognoa inc. , palo alto , ca , usa www.linkedin.com/in/halimabba , 2eric_g @ ericglover.com , 3depart pediatr , stanford univers , stanford , ca , usa , 4depart biomed data scienc , stanford univers , stanford , ca , usa correspond : cognoa inc. , palo alto , ca , usa ; halim @ cognoa.com receiv 19 septemb 2017 ; revis 16 march 2018 ; editori decis
# Question: What are methods to detect Autism from home videos?
# Relevant text, if any:
# The research team at Cognoa Inc., led by Halim Abbas, Ford Garberson, Eric Glover, Denise P. Wall, and colleagues, has developed an approach to detect autism using machine learning algorithms on early childhood home videos. The team's method combines data from a standardized questionnaire and video analysis to improve the accuracy of autism diagnosis. The approach has been shown to have high accuracy in a study published in the Journal of Autism and Developmental Disorders.
#
# The team used a dataset of home videos of children aged 12-36 months, which were annotated by experts in autism diagnosis. They applied machine learning algorithms to extract features from the videos, such as facial expressions, body movements, and vocalizations. They also used data from a standardized questionnaire, the Modified Checklist for Autism in Toddlers (M-CHAT), to improve the accuracy of the diagnosis.
#
# The team's method achieved an area under the receiver operating characteristic curve (AUC-ROC) of 0.87, which is considered high for autism diagnosis. The team plans to make the method available to clinicians and researchers through a web-based platform.
#
# Therefore, the methods to detect autism from home videos include using machine learning algorithms on video data and combining it with data from a standardized questionnaire. The team at Cognoa Inc. has developed such an approach and achieved high accuracy in a study.
# =========
# FINAL ANSWER: The methods to detect Autism from home videos include using machine learning algorithms on video data and combining it with data from a standardized questionnaire. The team at Cognoa Inc. has developed such an approach and achieved high accuracy in a study.

# %%
question = "How early infants cry can help in the early detection of Autism?"
result = qa.run({"query": question})
print(result)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Given the following extracted parts of a long document and a question, create a final answer.
# If you don't know the answer, just say that you don't know. Don't try to make up an answer.
#
# QUESTION: Which state/country's law governs the interpretation of the contract?
# =========
# Content: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.
#
# Content: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.
#
# 11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.
#
# 11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.
#
# 11.9 No Third-Party Beneficiaries.
#
# Content: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,
# =========
# FINAL ANSWER: This Agreement is governed by English law.
#
# QUESTION: What did the president say about Michael Jackson?
# =========
# Content: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.
#
# Last year COVID-19 kept us apart. This year we are finally together again.
#
# Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.
#
# With a duty to one another to the American people to the Constitution.
#
# And with an unwavering resolve that freedom will always triumph over tyranny.
#
# Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated.
#
# He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined.
#
# He met the Ukrainian people.
#
# From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world.
#
# Groups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.
#
# Content: And we won’t stop.
#
# We have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life.
#
# Let’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.
#
# Let’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.
#
# We can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together.
#
# I recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera.
#
# They were responding to a 9-1-1 call when a man shot and killed them with a stolen gun.
#
# Officer Mora was 27 years old.
#
# Officer Rivera was 22.
#
# Both Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers.
#
# I spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.
#
# Content: And a proud Ukrainian people, who have known 30 years  of independence, have repeatedly shown that they will not tolerate anyone who tries to take their country backwards.
#
# To all Americans, I will be honest with you, as I’ve always promised. A Russian dictator, invading a foreign country, has costs around the world.
#
# And I’m taking robust action to make sure the pain of our sanctions  is targeted at Russia’s economy. And I will use every tool at our disposal to protect American businesses and consumers.
#
# Tonight, I can announce that the United States has worked with 30 other countries to release 60 Million barrels of oil from reserves around the world.
#
# America will lead that effort, releasing 30 Million barrels from our own Strategic Petroleum Reserve. And we stand ready to do more if necessary, unified with our allies.
#
# These steps will help blunt gas prices here at home. And I know the news about what’s happening can seem alarming.
#
# But I want you to know that we are going to be okay.
#
# Content: More support for patients and families.
#
# To get there, I call on Congress to fund ARPA-H, the Advanced Research Projects Agency for Health.
#
# It’s based on DARPA—the Defense Department project that led to the Internet, GPS, and so much more.
#
# ARPA-H will have a singular purpose—to drive breakthroughs in cancer, Alzheimer’s, diabetes, and more.
#
# A unity agenda for the nation.
#
# We can do this.
#
# My fellow Americans—tonight , we have gathered in a sacred space—the citadel of our democracy.
#
# In this Capitol, generation after generation, Americans have debated great questions amid great strife, and have done great things.
#
# We have fought for freedom, expanded liberty, defeated totalitarianism and terror.
#
# And built the strongest, freest, and most prosperous nation the world has ever known.
#
# Now is the hour.
#
# Our moment of responsibility.
#
# Our test of resolve and conscience, of history itself.
#
# It is in this moment that our character is formed. Our purpose is found. Our future is forged.
#
# Well I know this nation.
# =========
# FINAL ANSWER: The president did not mention Michael Jackson.
#
# QUESTION: How early infants cry can help in the early detection of Autism?
# =========
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# toddler : initi studi investig earli detect autism pervas development disord . j autism dev disord . ( 2001 ) 31:131–44 . doi : 10.1023/a:1010738829569 23. legerste , markova g. intent make diﬀer : infant respons still-fac modiﬁ still-fac condit . infant behav dev . ( 2007 ) 30:232– 50. doi : 10.1016/j.infbeh.2007.02.008 24. yato , kawai , negayama k , sogon , tomiwa k , yamamoto h. infant respons matern still-fac 4 9 month . infant behav dev . ( 2008 ) 31:570–7 . doi : 10.1016/j.infbeh.2008.07.008 25.
# Question: How early infants cry can help in the early detection of Autism?
# Relevant text, if any:
# 20. toddler : initi studi investig earli detect autism pervas development disord. j autism dev disord. ( 2001 ) 31:131–44. doi : 10.1023/a:1010738829569
# This study investigates the early detection of autism and pervasive developmental disorders using the cry behavior of toddlers. The researchers found that infants with autism showed distinct cry patterns compared to typically developing infants. These findings suggest that cry analysis may be a useful tool in the early identification of autism.
#
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# develop . soc . cogn . affect neurosci . 9 , 538–543 ( 2014 ) . 40. jone , w. & klin , a. attent eye present declin 2-6-month- old infant later diagnos autism . natur 504 , 427–431 ( 2013 ) . 41. paul , r. , fuerst , y. , ramsay , g. , chawarska , k. & klin , a. mouth babe : vocal product infant sibl child asd . j. child psychol . psychiatri 52 , 588–598 ( 2011 ) . 42. sheinkopf , s. j. , iverson , j. m. , rinaldi , m. l. & lester , b. m. atyp cri acoust 6-month-old infant risk autism spectrum disord .
# Question: How early infants cry can help in the early detection of Autism?
# Relevant text, if any:
# The study by Jons et al. (2013) found that 2-6-month-old infants who later received a diagnosis of autism had a decreased attention to eye contact during a standardized test compared to typically developing infants. Paul et al. (2011) found that vocalizations produced by 6-month-old infants at risk for autism spectrum disorders were less varied and less socially engaging than those produced by typically developing infants. Sheinkopf et al. (2014) also found that atypical cry acoustics in 6-month-old infants were associated with an increased risk for autism spectrum disorders. These studies suggest that early differences in attention, vocalizations, and cry acoustics may be useful markers for identifying infants at risk for autism spectrum disorders.
# Therefore, the early cry of an infant can potentially help in the early detection of Autism as studies have shown that atypical cry acoustics in 6-month-old infants are associated with an increased risk for autism spectrum disorders.
# =========
# FINAL ANSWER: Yes, the early cry of an infant can potentially help in the early detection of Autism. Studies have shown that atypical cry acoustics in 6-month-old infants are associated with an increased risk for autism spectrum disorders.

# %%
question = "What is Still-Face Paradigm in Early Screening for High-Risk Autism Spectrum Disorder"
result = qa.run({"query": question})
print(result)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Given the following extracted parts of a long document and a question, create a final answer.
# If you don't know the answer, just say that you don't know. Don't try to make up an answer.
#
# QUESTION: Which state/country's law governs the interpretation of the contract?
# =========
# Content: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.
#
# Content: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.
#
# 11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.
#
# 11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.
#
# 11.9 No Third-Party Beneficiaries.
#
# Content: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,
# =========
# FINAL ANSWER: This Agreement is governed by English law.
#
# QUESTION: What did the president say about Michael Jackson?
# =========
# Content: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.
#
# Last year COVID-19 kept us apart. This year we are finally together again.
#
# Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.
#
# With a duty to one another to the American people to the Constitution.
#
# And with an unwavering resolve that freedom will always triumph over tyranny.
#
# Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated.
#
# He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined.
#
# He met the Ukrainian people.
#
# From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world.
#
# Groups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.
#
# Content: And we won’t stop.
#
# We have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life.
#
# Let’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.
#
# Let’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.
#
# We can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together.
#
# I recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera.
#
# They were responding to a 9-1-1 call when a man shot and killed them with a stolen gun.
#
# Officer Mora was 27 years old.
#
# Officer Rivera was 22.
#
# Both Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers.
#
# I spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.
#
# Content: And a proud Ukrainian people, who have known 30 years  of independence, have repeatedly shown that they will not tolerate anyone who tries to take their country backwards.
#
# To all Americans, I will be honest with you, as I’ve always promised. A Russian dictator, invading a foreign country, has costs around the world.
#
# And I’m taking robust action to make sure the pain of our sanctions  is targeted at Russia’s economy. And I will use every tool at our disposal to protect American businesses and consumers.
#
# Tonight, I can announce that the United States has worked with 30 other countries to release 60 Million barrels of oil from reserves around the world.
#
# America will lead that effort, releasing 30 Million barrels from our own Strategic Petroleum Reserve. And we stand ready to do more if necessary, unified with our allies.
#
# These steps will help blunt gas prices here at home. And I know the news about what’s happening can seem alarming.
#
# But I want you to know that we are going to be okay.
#
# Content: More support for patients and families.
#
# To get there, I call on Congress to fund ARPA-H, the Advanced Research Projects Agency for Health.
#
# It’s based on DARPA—the Defense Department project that led to the Internet, GPS, and so much more.
#
# ARPA-H will have a singular purpose—to drive breakthroughs in cancer, Alzheimer’s, diabetes, and more.
#
# A unity agenda for the nation.
#
# We can do this.
#
# My fellow Americans—tonight , we have gathered in a sacred space—the citadel of our democracy.
#
# In this Capitol, generation after generation, Americans have debated great questions amid great strife, and have done great things.
#
# We have fought for freedom, expanded liberty, defeated totalitarianism and terror.
#
# And built the strongest, freest, and most prosperous nation the world has ever known.
#
# Now is the hour.
#
# Our moment of responsibility.
#
# Our test of resolve and conscience, of history itself.
#
# It is in this moment that our character is formed. Our purpose is found. Our future is forged.
#
# Well I know this nation.
# =========
# FINAL ANSWER: The president did not mention Michael Jackson.
#
# QUESTION: What is Still-Face Paradigm in Early Screening for High-Risk Autism Spectrum Disorder
# =========
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# 8 june 2020 | volum 8 | articl 290 qiu et al . earli screen high-risk asd autism spectrum disord : examin broad phenotyp . j autism dev disord . ( 2007 ) 37:122–32 . doi : 10.1007/s10803-006-0337-1 11. heimann , laberg ke , nordøen b. imit interact increas social interest elicit imit non-verb child autism . infant child dev . ( 2010 ) 15:297–309 . doi : 10.1002/icd.463 12. harker cm , ibanez lv , nguyen tp , messing d , stone wl . eﬀect parent style social smile infant high low risk asd . j autism dev
# Question: What is Still-Face Paradigm in Early Screening for High-Risk Autism Spectrum Disorder
# Relevant text, if any:
# The Still-Face Experiment, developed by Tronick and his colleagues (Tronick, 1978), is a well-known procedure used to examine the broad phenotypic features of infants at risk for autism spectrum disorder (ASD) (Qiu et al., 2007). In this paradigm, the mother is instructed to maintain a still-face expression for a period of time while interacting with her infant. The infant's responses to the mother's still-face expression are then assessed. The Still-Face Experiment has been found to be a useful tool in identifying infants who are at high risk for developing ASD (Heimann, Laberg, & Nordøen, 2010). For example, infants with ASD may show decreased social interest and may not elicit imitative behavior in response to their mother's still-face expression (Heimann et al., 2010). Additionally, parents of infants with ASD may have a different parenting style, such as less use of social smiles, compared to parents of infants without ASD (Harker, Ibanez, Nguyen, Messing, & Stone, 2006).
# Therefore, the Still-Face Paradigm is a method used in early screening for high-risk autism spectrum disorder to examine the infant's response to a still-face expression of the mother and the mother's use of social smiles during interaction. Infants with autism spectrum disorder may show decreased social interest and less imitative behavior in response to the mother's still-face expression, and parents of infants with autism spectrum disorder may have a different parenting style, such as less use of social smiles.
#
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# yeargin-allsopp , lee lc , harrington r , lopez , fitzgerald rt , hewitt , pettygrov , constantino jn , vehorn , shenouda , hall-land j , van naarden-braun k , dowl nf . ( 2018 ) . preval autism spectrum disord among child age 8 year : autism development disabl monitor network , 11 site , unit state 2014. mmwr surveil summari , 67 ( 6 ) , 1–23 . barger bd , campbel jm , mcdonough jd . ( 2013 ) . preval onset regress within autism spectrum disord : meta-analyt review . journal autism development disord , 43
# Question: What is Still-Face Paradigm in Early Screening for High-Risk Autism Spectrum Disorder
# Relevant text, if any:
# The Autism Developmental Disabilities Monitoring (ADDM) Network conducted a study across 11 sites in 2014 to determine the prevalence of autism spectrum disorder (ASD) among children aged 8 years. The study found that the prevalence of ASD was 1 in 54 children.
# Barger, Campbell, and McDonough (2013) conducted a meta-analytic review of studies on the onset and regression in autism spectrum disorder. They found that regression in autism spectrum disorder was more common than previously thought, with a prevalence of approximately 30%.
# The text does not provide any information on the Still-Face Paradigm in early screening for high-risk autism spectrum disorder.
# =========
# FINAL ANSWER: The text does not provide any information on the Still-Face Paradigm in early screening for high-risk autism spectrum disorder.

# %%
question = "What is West Syndrome?"
result = qa.run({"query": question})
print(result)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Given the following extracted parts of a long document and a question, create a final answer.
# If you don't know the answer, just say that you don't know. Don't try to make up an answer.
#
# QUESTION: Which state/country's law governs the interpretation of the contract?
# =========
# Content: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.
#
# Content: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.
#
# 11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.
#
# 11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.
#
# 11.9 No Third-Party Beneficiaries.
#
# Content: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,
# =========
# FINAL ANSWER: This Agreement is governed by English law.
#
# QUESTION: What did the president say about Michael Jackson?
# =========
# Content: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.
#
# Last year COVID-19 kept us apart. This year we are finally together again.
#
# Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.
#
# With a duty to one another to the American people to the Constitution.
#
# And with an unwavering resolve that freedom will always triumph over tyranny.
#
# Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated.
#
# He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined.
#
# He met the Ukrainian people.
#
# From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world.
#
# Groups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.
#
# Content: And we won’t stop.
#
# We have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life.
#
# Let’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.
#
# Let’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.
#
# We can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together.
#
# I recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera.
#
# They were responding to a 9-1-1 call when a man shot and killed them with a stolen gun.
#
# Officer Mora was 27 years old.
#
# Officer Rivera was 22.
#
# Both Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers.
#
# I spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.
#
# Content: And a proud Ukrainian people, who have known 30 years  of independence, have repeatedly shown that they will not tolerate anyone who tries to take their country backwards.
#
# To all Americans, I will be honest with you, as I’ve always promised. A Russian dictator, invading a foreign country, has costs around the world.
#
# And I’m taking robust action to make sure the pain of our sanctions  is targeted at Russia’s economy. And I will use every tool at our disposal to protect American businesses and consumers.
#
# Tonight, I can announce that the United States has worked with 30 other countries to release 60 Million barrels of oil from reserves around the world.
#
# America will lead that effort, releasing 30 Million barrels from our own Strategic Petroleum Reserve. And we stand ready to do more if necessary, unified with our allies.
#
# These steps will help blunt gas prices here at home. And I know the news about what’s happening can seem alarming.
#
# But I want you to know that we are going to be okay.
#
# Content: More support for patients and families.
#
# To get there, I call on Congress to fund ARPA-H, the Advanced Research Projects Agency for Health.
#
# It’s based on DARPA—the Defense Department project that led to the Internet, GPS, and so much more.
#
# ARPA-H will have a singular purpose—to drive breakthroughs in cancer, Alzheimer’s, diabetes, and more.
#
# A unity agenda for the nation.
#
# We can do this.
#
# My fellow Americans—tonight , we have gathered in a sacred space—the citadel of our democracy.
#
# In this Capitol, generation after generation, Americans have debated great questions amid great strife, and have done great things.
#
# We have fought for freedom, expanded liberty, defeated totalitarianism and terror.
#
# And built the strongest, freest, and most prosperous nation the world has ever known.
#
# Now is the hour.
#
# Our moment of responsibility.
#
# Our test of resolve and conscience, of history itself.
#
# It is in this moment that our character is formed. Our purpose is found. Our future is forged.
#
# Well I know this nation.
# =========
# FINAL ANSWER: The president did not mention Michael Jackson.
#
# QUESTION: What is West Syndrome?
# =========
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# 42. baron-cohen s. autism : empathizing-system ( e- ) theori . ann n acad sci . ( 2009 ) 1156:68–80 . doi : 10.1111/j.1749-6632.2009 . 04467.x 43. baron-cohen , lombardo mv , auyeung b , ashwin e , knickmey r. autism spectrum condit preval male ? plo biol . ( 2011 ) 9 : e1001081 . doi : 10.1371/journal.pbio.10 01081 44. markram h , tania r , kamila m. intens world syndrome–an altern hypothesi autism . front neurosci . ( 2007 ) 1:77–96 . doi : 10.3389/neuro.01.1.1.006.2007 45. samson ac , huber , gross jj .
# Question: What is West Syndrome?
# Relevant text, if any:
# There is no text in the provided documents that directly answers the question "What is West Syndrome?". The documents provided discuss various topics related to autism, including theories about the condition, prevalence, and alternative hypotheses. However, none of them mention or describe West Syndrome.
#
# Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# poorer abil maintain midlin posit head 9–20 week age7 . author use visual 1duke center autism brain develop , depart psychiatri behavior scienc , duke univers , durham , north carolina , usa . 2univers utah , salt lake citi , utah , usa . 3depart electr comput engin , duke univers , durham , north carolina , usa . 4depart popul health scienc , duke univers , durham , north carolina , usa . 5nyu langon child studi center , new york univers , new york , new york , usa . 6depart pediatr , duke univers ,
# Question: What is West Syndrome?
# Relevant text, if any:
# West Syndrome is a neurological disorder characterized by infantile spasms and developmental delay. It typically affects children between the ages of 9-20 weeks. The authors of a study on this condition used data from the Duke Center for Autism and Brain Development, the University of Utah, the Duke University Department of Electrical and Computer Engineering, the Duke University Department of Population Health Sciences, and the NYU Langone Child Study Center. The study aimed to investigate the brain development in children with West Syndrome and depart from traditional psychiatric and behavioral science approaches.
# =========
# FINAL ANSWER: West Syndrome is a neurological disorder characterized by infantile spasms and developmental delay, typically affecting children between the ages of 9-20 weeks. The authors of a study on this condition used data from various institutions to investigate the brain development in children with West Syndrome.
